# %%
# !pip install simpy
import simpy
import random
import statistics
import networkx as nx
import matplotlib.pyplot as plt
import copy
from contextlib import redirect_stdout
# Out:
# Requirement already satisfied: simpy in /usr/local/lib/python3.10/dist-packages (4.1.1)

# %%
import random
import simpy
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import sys
import pandas as pd


# 重定向输出到文件
original_stdout = sys.stdout
#sys.stdout = open("simulation_output.txt", "w")
sys.stdout = original_stdout

TOTAL_PIECES = 10  # 总共的文件块数 / Total number of file pieces
SIMULATION_TIME = 100  # 模拟的总时长 / Total simulation time
REQUEST_TIMEOUT = 10

class RequestStrategy:
    @staticmethod
    def random_peer_selection(missing_pieces, peers, requesting_pieces, animation, env, request_piece):
        """
        随机选择拥有目标片段的对等节点并发送请求
        :param missing_pieces: 需要下载的文件块
        :param peers: 当前对等节点列表
        :param requesting_pieces: 当前已经在请求的文件块
        :param animation: 动画对象，用于更新节点之间的连接
        :param env: SimPy 环境
        :param request_piece: 请求文件块的函数
        :return: 请求任务列表
        """
        request_tasks = []

        for piece in missing_pieces:
            if piece in requesting_pieces:
                continue

            shuffled_peers = peers[:]  # 复制 peers 列表
            random.shuffle(shuffled_peers)  # 随机打乱顺序

            for target_peer in shuffled_peers:
                if piece in target_peer.file_pieces:
                    # 动画更新连接
                    if animation:
                        animation.connect_peers(target_peer.id, env.now)

                    # 添加请求任务
                    request_tasks.append(env.process(request_piece(piece, target_peer)))
                    requesting_pieces.add(piece)
                    break  # 一旦找到拥有片段的节点，立即停止查找

        return request_tasks

    @staticmethod

    @staticmethod
    def avoid_excessive_requests(missing_pieces, peers, requesting_pieces, animation, env, request_piece):
        """
        避免对同一个 Peer 过多请求，并优先考虑稀缺性文件块。
        """
        request_tasks = []
        peer_request_count = {peer.id: 0 for peer in peers}  # 每个 Peer 拥有的目标文件块数量

        # 初始化 peer_request_count：记录每个节点拥有的目标文件块数量
        for piece in missing_pieces:
            for peer in peers:
                if piece in peer.file_pieces:
                    peer_request_count[peer.id] += 1

        # 计算每个文件块的稀缺性（拥有它的节点数量）
        piece_scarcity = {piece: 0 for piece in missing_pieces}
        for piece in missing_pieces:
            piece_scarcity[piece] = sum(1 for peer in peers if piece in peer.file_pieces)

        # 按稀缺性排序文件块（稀缺性高的优先）
        sorted_pieces = sorted(missing_pieces, key=lambda piece: piece_scarcity[piece])

        # 遍历按稀缺性排序后的文件块
        for piece in sorted_pieces:
            if piece in requesting_pieces:
                continue

            # 找到所有拥有该文件块的 Peer
            potential_peers = [peer for peer in peers if piece in peer.file_pieces]

            # 按 Peer 的拥有文件块数量排序（较少的优先）
            potential_peers.sort(key=lambda peer: peer_request_count[peer.id])

            # 如果有多个候选节点，优先请求拥有较少目标文件块的节点
            for target_peer in potential_peers:
                # 发起请求
                if animation:
                    animation.connect_peers(target_peer.id, env.now)
                request_tasks.append(env.process(request_piece(piece, target_peer)))
                requesting_pieces.add(piece)

                # 更新目标节点和其他候选节点的文件块数量
                peer_request_count[target_peer.id] += 10  # 减少目标节点的拥有文件块数量
                for peer in potential_peers:
                    if peer.id != target_peer.id:
                        peer_request_count[peer.id] -= 1

                break  # 成功请求后跳出循环

        return request_tasks



class Strategy:
    @staticmethod
    def equal_distribution_strategy(peer, target_peer_id):
        """根据当前的请求数，均匀分配上传带宽 / Evenly distribute upload bandwidth based on current number of requests"""
        number_of_requests = peer.current_requests
        available_bandwidth_per_request = peer.upload_speed / max(1, number_of_requests)  # 防止除0
        return available_bandwidth_per_request

    @staticmethod
    def tit_for_tat(peer, target_peer_id):
        """根据对方从当前用户得到的总下载量占比分配带宽 / Allocate bandwidth based on the ratio of what the target peer has uploaded"""
        total_downloaded = peer.total_downloaded
        if total_downloaded == 0:
            # 如果当前用户还没有下载任何东西，则按平等策略分配
            return Strategy.equal_distribution_strategy(peer, target_peer_id)

        # 获取目标 peer 从当前 peer 这里下载的总量
        download_from_peer = peer.upload_history.get(target_peer_id, 0)
        # 按照 tit-for-tat 策略计算带宽占比
        bandwidth_ratio = download_from_peer / total_downloaded
        available_bandwidth = bandwidth_ratio * peer.upload_speed
        return available_bandwidth

    def random_bandwidth_distribution(peer):
        """随机生成带宽分配并保存到 bandwidth_allocation 中 / Randomly generate bandwidth allocation and save it"""
        total_bandwidth = peer.upload_speed
        number_of_peers = len(peer.peers)
        allocations = {}

        # 随机分配带宽给每个请求的 peer
        for p in peer.peers:
            allocation = random.uniform(0, total_bandwidth / max(1, number_of_peers))
            allocations[p.id] = allocation
            total_bandwidth -= allocation

        # 保存分配到 peer 的 bandwidth_allocation 中
        peer.bandwidth_allocation = allocations

    @staticmethod
    def allocate_bandwidth(peer, target_peer_id):
        """根据带宽分配表分配带宽，如果表为空则随机分配 / Allocate bandwidth based on existing allocation, or randomly if none exists"""
        if not peer.bandwidth_allocation:
            Strategy.random_bandwidth_distribution(peer)

        # 按照分配表分配带宽
        return peer.bandwidth_allocation.get(target_peer_id, 0)

    def demand_priority(peer, target_peer_id):
        """
        优先上传需求最小的 peer 的策略 /
        Prioritize peers with the smallest demand
        """
        total_requests = sum(len(request_list) for request_list in peer.request_count_dict.values())

        if total_requests == 0:
            # 如果没有请求，则平均分配带宽
            return peer.upload_speed / len(peer.peers)

        # 计算目标 peer 的需求权重（需求越小，权重越高）
        target_requests = len(peer.request_count_dict.get(target_peer_id, []))
        if target_requests == 0:
            # 如果目标 peer 没有请求过文件，分配最低优先级的带宽
            return peer.upload_speed / len(peer.peers)

        demand_ratio = (1 / target_requests) / sum(
          1 / len(request_list) for request_list in peer.request_count_dict.values() if len(request_list) > 0
      )
        # 分配的带宽比例
        allocated_bandwidth = demand_ratio * peer.upload_speed
        return allocated_bandwidth

    def free_rider_strategy(peer, target_peer_id):
        """不上传任何东西 / Do not upload anything (Free Rider strategy)"""
        return 0

class Peer:
    def __init__(self, env, id, upload_speed, download_speed, animation, strategy, request_strategy):
        self.env = env
        self.id = id
        self.upload_speed = upload_speed  # 上传带宽 / Upload bandwidth
        self.download_speed = download_speed  # 下载带宽 / Download bandwidth
        self.file_pieces = set()  # 当前拥有的文件块 / File pieces currently owned
        self.peers = []  # 其他对等节点 / Other peers
        self.upload_resource = simpy.Resource(env, capacity=upload_speed)  # 上传带宽作为资源 / Upload bandwidth as a resource
        self.current_requests = 0  # 当前的请求数 / Current number of requests
        self.upload_history = {}  # 记录上传历史 / Dictionary to track upload history
        self.total_downloaded = 0  # 记录总共下载的文件大小 / Total downloaded file size
        self.bandwidth_allocation = {}  # 带宽分配，记录对每个 peer 的分配情况 / Dictionary to store bandwidth allocation
        self.download_times = {}
        self.request_count_dict = {}
        self.env.process(self.run())
        self.animation = animation  # 引入 Animation 对象
        self.strategy = strategy  # 当前 peer 的带宽分配策略
        self.request_strategy = request_strategy
        self.bandwidth_stability_timer = 0  # 带宽稳定计时器 / Bandwidth stability timer
        self.last_bandwidth = 0  # 上一次的带宽值 / Last bandwidth value
        self.bandwidth_check_interval = 1  # 带宽检查的时间间隔 / Bandwidth check interval (seconds)


    def add_peer(self, peer):
        self.peers.append(peer)

    def request_piece(self, piece, target):
        """请求特定文件块并动态调整带宽 / Request a specific file piece and dynamically adjust bandwidth"""
        if piece in target.file_pieces:
            #print(f'Time {self.env.now}: Peer {self.id} requests file piece {piece} from Peer {target.id}')
            request_log.append({
                'time': self.env.now,
                'from_peer': self.id,
                'to_peer': target.id,
                'piece': piece
            })

            if self.id not in target.request_count_dict:
                    target.request_count_dict[self.id] = []

                # 将请求添加到目标Peer的请求列表
            target.request_count_dict[self.id].append(piece)
            while target.request_count_dict[self.id][0] != piece:
              yield self.env.timeout(0.1)

            with target.upload_resource.request() as req:
                target.current_requests += 1
                piece_size = Peer.piece_size
                downloaded = 0 # 初始化已下载部分 / Initialize downloaded portion
                last_downloaded = downloaded  # 用于记录上一次的已下载数据
                start_time = self.env.now  # 请求的起始时间
                no_progress_time = 0  # 无下载进展的计时

                while downloaded < piece_size:
                    # 根据 target peer 的策略分配带宽
                    if target.strategy == "tit_for_tat":
                        available_bandwidth_per_request = Strategy.tit_for_tat(target, self.id)
                    elif target.strategy == "random_bandwidth":
                        available_bandwidth_per_request = Strategy.allocate_bandwidth(target, self.id)
                    elif target.strategy == "demand_priority":
                        available_bandwidth_per_request = Strategy.demand_priority(target, self.id)
                    elif target.strategy == "free_rider_strategy":
                        available_bandwidth_per_request = Strategy.free_rider_strategy(target, self.id)
                    else:
                        available_bandwidth_per_request = Strategy.equal_distribution_strategy(target, self.id)

                    data_per_step = available_bandwidth_per_request * 0.1  # 假设时间步为 0.1 秒

                    downloaded += data_per_step

                    if downloaded - last_downloaded < 1e-3:  # 进展微小，视为无进展
                        no_progress_time += 0.1  # 增加无进展时间
                    else:
                        no_progress_time = 0  # 重置无进展时间
                        last_downloaded = downloaded
                      # 超时处理逻辑：当无进展时间超过设定阈值时
                    if no_progress_time >= REQUEST_TIMEOUT:
                        #print(f"Time {self.env.now}: Peer {self.id} request for piece {piece} timed out due to no progress.")
                        target.request_count_dict[self.id].remove(piece)
                        target.current_requests -= 1
                        return  # 退出当前请求并标记为失败
                    yield self.env.timeout(0.1)
                    # 计算进度百分比
                    progress_percentage = (downloaded / piece_size) * 100
                    #print(f'Time {self.env.now:.1f}: Peer {self.id} has downloaded {progress_percentage:.1f}% of file piece {piece}')

                    # 调用动画更新进度
                    if self.animation:
                      self.animation.update_progress((target.id, self.id), round(progress_percentage, 2))

                target.current_requests -= 1
                target.request_count_dict[self.id].remove(piece)
                #print(f'Time {self.env.now}: Peer {self.id} completed download of piece {piece} from Peer {target.id}')
                self.file_pieces.add(piece)

                self.download_times[piece] = self.env.now
                #print(f'Time {self.env.now:.1f}: Peer {self.id} completed download of file piece {piece}')

                # 记录 target 传输给当前 peer 的总文件大小
                if target.id not in self.upload_history:
                    self.upload_history[target.id] = 0
                self.upload_history[target.id] += piece_size  # 将传输的文件块大小加入历史记录

                # 更新总下载文件大小
                self.total_downloaded += piece_size
                #print(f"Peer {self.id} received {piece_size} MB from Peer {target.id}. Total received: {self.upload_history[target.id]} MB")
                #print(f"Peer {self.id} has downloaded a total of {self.total_downloaded} MB")

        else:
            print(f"Time {self.env.now:.1f}: Peer {self.id} found that Peer {target.id} no longer has file piece {piece}")


    def run(self):
        while True:
            if len(self.file_pieces) == TOTAL_PIECES:
                break
            yield self.env.timeout(1)

            missing_pieces = set(range(TOTAL_PIECES)) - self.file_pieces
            if not missing_pieces:
                break

            requesting_pieces = set()
            # 调用 RequestStrategy 进行请求
            request_tasks = self.request_strategy(
                missing_pieces=missing_pieces,
                peers=self.peers,
                requesting_pieces=requesting_pieces,
                animation=self.animation,
                env=self.env,
                request_piece=self.request_piece
            )

            if request_tasks:
                yield self.env.all_of(request_tasks)
            unfinished_pieces = set(range(TOTAL_PIECES)) - self.file_pieces

            if unfinished_pieces:
                          #print(f"Time {self.env.now}: Peer {self.id} is retrying requests for unfinished pieces {unfinished_pieces}.")
                          retry_tasks = self.request_strategy(
                                              missing_pieces=unfinished_pieces,
                                              peers=self.peers,
                                              requesting_pieces=requesting_pieces,
                                              animation=self.animation,
                                              env=self.env,
                                              request_piece=self.request_piece
                                          )
                          if retry_tasks:
                                yield self.env.all_of(retry_tasks)

class Animation:
    def __init__(self, num_peers):
        self.num_peers = num_peers
        self.G = nx.DiGraph()
        self.pos = None
        self.edge_labels = {}
        self.fig, self.ax = plt.subplots()  # 创建画布
        self.updates = []  # 用于存储每一帧的更新（边和进度）
        self.frame_count = 0  # 记录调用 update_progress 的次数

    def generate_peers(self):
        """生成Peer节点"""
        self.G.add_node(0, label='Peer 0')
        for i in range(1, self.num_peers):
            self.G.add_node(i, label=f'Peer {i}')
        self.pos = nx.circular_layout(self.G)

    def connect_peers(self, from_peer, to_peer):
        """为成功请求的两个Peer之间连线"""
        if not self.G.has_edge(from_peer, to_peer):
            self.G.add_edge(from_peer, to_peer, progress=0)  # 为两个成功请求的节点添加一条边
        self.edge_labels[(from_peer, to_peer)] = '0%'

    def update_progress(self, edge, progress):
        """更新指定边的进度，并在动画中展示"""
        from_peer, to_peer = edge
        if self.G.has_edge(from_peer, to_peer):
            self.G[from_peer][to_peer]['progress'] = progress
            self.edge_labels[(from_peer, to_peer)] = f'{progress}%'

        # 每隔一定更新次数记录一次帧
        if self.frame_count % 1 == 0:  # 跳过一半的帧
            self.updates.append((edge, progress))
        self.frame_count += 1

    def animate(self, i):
        """逐帧更新图像的动画函数"""
        self.ax.clear()

        # 绘制节点和边
        nx.draw(self.G, self.pos, with_labels=True, labels=nx.get_node_attributes(self.G, 'label'),
                node_color='lightblue', node_size=1000, ax=self.ax)
        nx.draw_networkx_edges(self.G, self.pos, ax=self.ax)

        # 逐帧应用进度更新
        if i < len(self.updates):
            edge, progress = self.updates[i]
            from_peer, to_peer = edge
            self.edge_labels[(from_peer, to_peer)] = f'{progress}%'

        # 绘制边上的进度标签
        nx.draw_networkx_edge_labels(self.G, self.pos, edge_labels=self.edge_labels, ax=self.ax)

    def save_animation(self, filename='animation.mp4', target_duration=100):

      effective_frames = len(self.updates)  # 实际记录的有效帧数
      if effective_frames > 0:
          # 动态计算帧间隔，确保总时长不超过 target_duration
          interval = (target_duration * 1000) / effective_frames  # 单位：毫秒
          interval = max(1, interval)  # 确保帧间隔不低于 20 毫秒
      else:
          interval = 100  # 默认间隔

      # 使用有效帧数作为 frames
      anim = FuncAnimation(self.fig, self.animate, frames=effective_frames, interval=interval, repeat=False)
      anim.save(filename, writer='ffmpeg')
      print(f"Animation saved as {filename} with {effective_frames} frames and interval {interval:.1f} ms.")

request_log = []

def run_simulation(num_peers, enable_animation=True):
    env = simpy.Environment()
    peers = []
    animation = None  # 创建动画实例
    piece_download_matrix = [["" for _ in range(TOTAL_PIECES)] for _ in range(num_peers)]
    time_matrix = [["——" for _ in range(TOTAL_PIECES)] for _ in range(num_peers)]

    if enable_animation:
        animation = Animation(num_peers)  # 创建动画实例
        animation.generate_peers()

    Peer.file_size = random.uniform(10, 20)  # 假设文件大小在10MB到20MB之间
    Peer.piece_size = Peer.file_size / TOTAL_PIECES

    # 创建多个对等节点
    print("Peer Initial Values:")
    print("{:<10}{:<15}{:<15}{:<25}{:<30}".format("Peer ID", "Upload BW", "Download BW", "Strategy", "Request Strategy"))
    for i in range(num_peers):
        upload_speed = random.randint(1, 5)
        download_speed = random.randint(30, 50)

        # 随机选择上传策略和请求策略
        strategy = random.choice(
            ["random_bandwidth", "tit_for_tat", "equal_distribution_strategy", "demand_priority", "free_rider_strategy"]
        )
        request_strategy = random.choice(
            [RequestStrategy.random_peer_selection, RequestStrategy.avoid_excessive_requests]
        )

        peer = Peer(env, i, upload_speed, download_speed, animation, strategy, request_strategy)
        peers.append(peer)

        # 打印每个 Peer 的信息
        print("{:<10}{:<15.2f}{:<15.2f}{:<25}{:<30}".format(
            i, upload_speed, download_speed, strategy, request_strategy.__name__
        ))

        num_pieces = random.randint(0, TOTAL_PIECES - 1)
        peer.file_pieces = set(random.sample(range(TOTAL_PIECES), num_pieces))

    all_pieces = list(range(TOTAL_PIECES))  # 文件块的编号
    random.shuffle(all_pieces)
    for index, piece in enumerate(all_pieces):
        peer_id = index % num_peers
        peers[peer_id].file_pieces.add(piece)

    # 连接所有对等节点
    for peer in peers:
        for other_peer in peers:
            if peer != other_peer:
                peer.add_peer(other_peer)

    # 运行模拟
    env.run(until=SIMULATION_TIME)

    print("\nDownload Times:")
    for peer in peers:
        print(f"Peer {peer.id}:")
        for piece, time in sorted(peer.download_times.items()):
            print(f"  File piece {piece}: completed at time {time:.1f}")

    for log in request_log:
        from_peer = log["from_peer"]
        to_peer = log["to_peer"]
        piece = log["piece"]
        piece_download_matrix[from_peer][piece] = f"{piece}.Peer{to_peer}"

    # 填充时间矩阵
    for peer in peers:
        for piece, time in sorted(peer.download_times.items()):
            time_matrix[peer.id][piece] = f"{time:.1f}"
        for log in request_log:
            if log["from_peer"] == peer.id and time_matrix[peer.id][log["piece"]] == "——":
                time_matrix[peer.id][log["piece"]] = "non-finished"

    # 计算每个Peer的总完成时间
    total_finished_time = []
    for peer in peers:
        finished_times = [time for time in peer.download_times.values()]
        total_time = max(finished_times) if finished_times else "non-finished"
        total_finished_time.append(total_time)

    # 输出 Piece Download Matrix
    print("\nPiece Download Matrix:")
    print(pd.DataFrame(
        piece_download_matrix,
        index=[f"Peer {i}" for i in range(num_peers)],
        columns=[f"Piece {i}" for i in range(TOTAL_PIECES)]
    ).to_string(index=True, line_width=1000))

    # 输出 Time Matrix
    print("\nTime Matrix:")
    print(pd.DataFrame(
        time_matrix,
        index=[f"Peer {i}" for i in range(num_peers)],
        columns=[f"Piece {i}" for i in range(TOTAL_PIECES)]
    ).to_string(index=True, line_width=1000))

    # 输出 Total Finished Time
    print("\nTotal Finished Time for Each Peer:")
    for i, peer in enumerate(peers):
        if any(time_matrix[i][j] == "non-finished" for j in range(TOTAL_PIECES)):
            # 如果该 Peer 的时间矩阵中有 "non-finished"，打印 "non-finished"
            print(f"Peer {i}: non-finished")
        else:
            # 如果没有 "non-finished"，计算总完成时间并打印保留一位小数
            finished_times = [time for time in peer.download_times.values()]
            total_time = max(finished_times) if finished_times else "non-finished"
            print(f"Peer {i}: {total_time:.1f}")

    print("\n")
    for peer in peers:
        if peer.download_times:
            avg_time = sum(peer.download_times.values()) / len(peer.download_times)
            print(f"Peer {peer.id}: Average download time = {avg_time:.2f}")
        else:
            print(f"Peer {peer.id}: No pieces downloaded.")

    # 保存动画为 mp4
    if enable_animation:
        target_video_duration = 60
        animation.save_animation(filename="animation.mp4", target_duration=target_video_duration)
        print(f"Animation saved as animation.mp4 with {animation.frame_count} frames.")
    else:
        print("Animation generation is disabled.")


def calculate_combined_averages(num_simulations, num_peers):
    """
    计算每种请求策略和带宽分配策略组合的平均下载时间。

    参数:
    - num_simulations: 模拟次数
    - num_peers: 每次模拟的节点数量

    返回:
    - 一个包含组合平均下载时间的字典
    """
    combined_results = {}

    # 初始化结果存储结构
    for request_strategy_name in ["random_peer_selection", "avoid_excessive_requests"]:
        combined_results[request_strategy_name] = {
            "random_bandwidth": [],
            "tit_for_tat": [],
            "equal_distribution_strategy": [],
            "demand_priority": [],
            "free_rider_strategy": []
        }

    for _ in range(num_simulations):
        env = simpy.Environment()
        peers = create_peers(env, num_peers, is_first_time=False)
        env.run(until=SIMULATION_TIME)

        for peer in peers:
            if peer.download_times:  # 如果该 Peer 下载了文件块
                avg_time = sum(peer.download_times.values()) / len(peer.download_times)
                strategy = peer.strategy
                request_strategy_name = peer.request_strategy.__name__
                combined_results[request_strategy_name][strategy].append(avg_time)

    # 计算平均值
    final_combined_averages = {}
    for request_strategy_name, strategies in combined_results.items():
        final_combined_averages[request_strategy_name] = {}
        for strategy, times in strategies.items():
            if times:
                final_combined_averages[request_strategy_name][strategy] = sum(times) / len(times)
            else:
                final_combined_averages[request_strategy_name][strategy] = None

    return final_combined_averages



def create_peers(env, num_peers, is_first_time):
    peers = []

    Peer.file_size = random.uniform(10, 20)  # 假设文件大小在10MB到20MB之间
    Peer.piece_size = Peer.file_size / TOTAL_PIECES

    for i in range(num_peers):
        upload_speed = random.randint(1, 5)
        download_speed = random.randint(30, 50)

        # 随机分配上传策略和请求策略
        strategy = random.choice(
            ["random_bandwidth", "tit_for_tat", "equal_distribution_strategy", "demand_priority", "free_rider_strategy"]
        )
        request_strategy = random.choice(
            [RequestStrategy.random_peer_selection, RequestStrategy.avoid_excessive_requests]
        )

        peer = Peer(env, i, upload_speed, download_speed, None, strategy, request_strategy)
        peers.append(peer)

        # 初始化文件块分配
        num_pieces = random.randint(0, TOTAL_PIECES - 1)
        peer.file_pieces = set(random.sample(range(TOTAL_PIECES), num_pieces))

    # 连接所有对等节点
    for peer in peers:
        for other_peer in peers:
            if peer != other_peer:
                peer.add_peer(other_peer)

    return peers



#final_averages = calculate_strategy_averages(num_simulations=300, num_peers=10)

run_simulation(20, False)
# Out:
# Peer Initial Values:
# Peer ID   Upload BW      Download BW    Strategy                 Request Strategy
# 0         4.00           31.00          random_bandwidth         avoid_excessive_requests
# 1         5.00           49.00          equal_distribution_strategyrandom_peer_selection
# 2         5.00           35.00          random_bandwidth         avoid_excessive_requests
# 3         2.00           48.00          free_rider_strategy      avoid_excessive_requests
# 4         5.00           41.00          random_bandwidth         random_peer_selection
# 5         3.00           37.00          random_bandwidth         avoid_excessive_requests
# 6         2.00           33.00          tit_for_tat              avoid_excessive_requests
# 7         4.00           40.00          equal_distribution_strategyavoid_excessive_requests
# 8         5.00           32.00          free_rider_strategy      avoid_excessive_requests
# 9         3.00           39.00          random_bandwidth         random_peer_selection
# 10        1.00           50.00          random_bandwidth         random_peer_selection
# 11        2.00           47.00          free_rider_strategy      random_peer_selection
# 12        5.00           46.00          demand_priority          random_peer_selection
# 13        2.00           33.00          demand_priority          random_peer_selection
# 14        4.00           41.00          equal_distribution_strategyrandom_peer_selection
# 15        2.00           30.00          tit_for_tat              avoid_excessive_requests
# 16        2.00           38.00          random_bandwidth         random_peer_selection
# 17        3.00           40.00          demand_priority          random_peer_selection
# 18        1.00           34.00          free_rider_strategy      avoid_excessive_requests
# 19        3.00           31.00          random_bandwidth         random_peer_selection
#
# Download Times:
# Peer 0:
#   File piece 0: completed at time 2.7
#   File piece 2: completed at time 11.6
#   File piece 4: completed at time 37.4
#   File piece 7: completed at time 6.1
#   File piece 8: completed at time 17.6
# Peer 1:
#   File piece 1: completed at time 11.7
#   File piece 3: completed at time 6.4
#   File piece 4: completed at time 3.0
#   File piece 6: completed at time 3.5
#   File piece 7: completed at time 4.2
#   File piece 8: completed at time 13.1
# Peer 2:
#   File piece 0: completed at time 3.0
#   File piece 2: completed at time 2.7
#   File piece 3: completed at time 9.8
#   File piece 4: completed at time 12.2
#   File piece 6: completed at time 91.5
#   File piece 7: completed at time 6.5
#   File piece 8: completed at time 7.9
# Peer 3:
#   File piece 0: completed at time 3.1
#   File piece 3: completed at time 6.5
#   File piece 4: completed at time 21.2
#   File piece 8: completed at time 15.5
# Peer 4:
#   File piece 0: completed at time 21.7
#   File piece 2: completed at time 1.6
#   File piece 3: completed at time 68.7
#   File piece 5: completed at time 54.1
#   File piece 6: completed at time 26.8
#   File piece 7: completed at time 52.6
# Peer 5:
#   File piece 0: completed at time 3.1
#   File piece 4: completed at time 11.2
# Peer 6:
#   File piece 0: completed at time 3.2
#   File piece 1: completed at time 9.7
#   File piece 6: completed at time 9.4
#   File piece 7: completed at time 6.5
#   File piece 9: completed at time 2.9
# Peer 7:
# Peer 8:
#   File piece 0: completed at time 3.2
#   File piece 1: completed at time 58.5
#   File piece 2: completed at time 2.9
#   File piece 3: completed at time 76.6
#   File piece 4: completed at time 59.9
#   File piece 6: completed at time 18.1
#   File piece 7: completed at time 6.5
#   File piece 8: completed at time 22.8
#   File piece 9: completed at time 81.3
# Peer 9:
#   File piece 1: completed at time 24.8
#   File piece 3: completed at time 3.3
#   File piece 4: completed at time 48.6
#   File piece 5: completed at time 61.0
# Peer 10:
#   File piece 0: completed at time 3.4
#   File piece 1: completed at time 93.7
#   File piece 3: completed at time 79.4
#   File piece 8: completed at time 77.8
# Peer 11:
#   File piece 8: completed at time 10.1
# Peer 12:
#   File piece 1: completed at time 18.2
#   File piece 3: completed at time 3.4
#   File piece 5: completed at time 60.1
#   File piece 8: completed at time 16.3
# Peer 13:
#   File piece 0: completed at time 1.4
#   File piece 1: completed at time 3.0
#   File piece 4: completed at time 8.1
#   File piece 5: completed at time 85.2
#   File piece 8: completed at time 37.7
#   File piece 9: completed at time 1.8
# Peer 14:
#   File piece 0: completed at time 23.6
#   File piece 3: completed at time 60.4
#   File piece 6: completed at time 3.4
#   File piece 8: completed at time 51.0
# Peer 15:
#   File piece 0: completed at time 3.2
#   File piece 1: completed at time 32.2
#   File piece 2: completed at time 69.8
#   File piece 4: completed at time 37.6
#   File piece 7: completed at time 6.6
#   File piece 8: completed at time 37.0
#   File piece 9: completed at time 74.6
# Peer 16:
# Peer 17:
#   File piece 0: completed at time 50.8
#   File piece 4: completed at time 3.4
#   File piece 5: completed at time 33.9
#   File piece 7: completed at time 4.3
#   File piece 8: completed at time 4.8
# Peer 18:
#   File piece 8: completed at time 14.5
# Peer 19:
#   File piece 1: completed at time 3.0
#   File piece 3: completed at time 12.6
#
# Piece Download Matrix:
#           Piece 0   Piece 1   Piece 2   Piece 3  Piece 4   Piece 5   Piece 6   Piece 7   Piece 8   Piece 9
# Peer 0    0.Peer1             2.Peer6            4.Peer4  5.Peer18            7.Peer13   8.Peer5   9.Peer3
# Peer 1              1.Peer2  2.Peer10  3.Peer13  4.Peer7   5.Peer3  6.Peer15   7.Peer7  8.Peer19   9.Peer3
# Peer 2    0.Peer1            2.Peer14   3.Peer0  4.Peer6  5.Peer18   6.Peer5  7.Peer13   8.Peer4   9.Peer3
# Peer 3    0.Peer1   1.Peer0   2.Peer6  3.Peer13  4.Peer4                                 8.Peer5
# Peer 4   0.Peer19            2.Peer17  3.Peer15           5.Peer14   6.Peer9   7.Peer9
# Peer 5    0.Peer1             2.Peer6   3.Peer0  4.Peer4   5.Peer8             7.Peer3
# Peer 6    0.Peer1   1.Peer2            3.Peer15            5.Peer8   6.Peer0  7.Peer13   8.Peer4  9.Peer14
# Peer 7                                                     5.Peer3
# Peer 8    0.Peer1   1.Peer2  2.Peer14   3.Peer0  4.Peer1             6.Peer0  7.Peer13   8.Peer4   9.Peer4
# Peer 9              1.Peer4             3.Peer7  4.Peer4  5.Peer12
# Peer 10   0.Peer7   1.Peer9            3.Peer17                                          8.Peer5
# Peer 11                                                                                  8.Peer4
# Peer 12            1.Peer13             3.Peer7           5.Peer16                      8.Peer19
# Peer 13  0.Peer12  1.Peer14  2.Peer11            4.Peer6  5.Peer10                       8.Peer5  9.Peer12
# Peer 14   0.Peer9                      3.Peer16                      6.Peer7  7.Peer10   8.Peer4
# Peer 15   0.Peer1   1.Peer0   2.Peer0            4.Peer4   5.Peer3            7.Peer13   8.Peer5   9.Peer5
# Peer 16                                                                                  8.Peer4
# Peer 17   0.Peer9  1.Peer19                      4.Peer7  5.Peer16             7.Peer7   8.Peer7
# Peer 18                                                                                  8.Peer4   9.Peer3
# Peer 19            1.Peer14            3.Peer17
#
# Time Matrix:
#         Piece 0       Piece 1       Piece 2       Piece 3 Piece 4       Piece 5 Piece 6       Piece 7       Piece 8       Piece 9
# Peer 0      2.7            ——          11.6            ——    37.4  non-finished      ——           6.1          17.6  non-finished
# Peer 1       ——          11.7  non-finished           6.4     3.0  non-finished     3.5           4.2          13.1  non-finished
# Peer 2      3.0            ——           2.7           9.8    12.2  non-finished    91.5           6.5           7.9  non-finished
# Peer 3      3.1  non-finished  non-finished           6.5    21.2            ——      ——            ——          15.5            ——
# Peer 4     21.7            ——           1.6          68.7      ——          54.1    26.8          52.6            ——            ——
# Peer 5      3.1            ——  non-finished  non-finished    11.2  non-finished      ——  non-finished            ——            ——
# Peer 6      3.2           9.7            ——  non-finished      ——  non-finished     9.4           6.5  non-finished           2.9
# Peer 7       ——            ——            ——            ——      ——  non-finished      ——            ——            ——            ——
# Peer 8      3.2          58.5           2.9          76.6    59.9            ——    18.1           6.5          22.8          81.3
# Peer 9       ——          24.8            ——           3.3    48.6          61.0      ——            ——            ——            ——
# Peer 10     3.4          93.7            ——          79.4      ——            ——      ——            ——          77.8            ——
# Peer 11      ——            ——            ——            ——      ——            ——      ——            ——          10.1            ——
# Peer 12      ——          18.2            ——           3.4      ——          60.1      ——            ——          16.3            ——
# Peer 13     1.4           3.0  non-finished            ——     8.1          85.2      ——            ——          37.7           1.8
# Peer 14    23.6            ——            ——          60.4      ——            ——     3.4  non-finished          51.0            ——
# Peer 15     3.2          32.2          69.8            ——    37.6  non-finished      ——           6.6          37.0          74.6
# Peer 16      ——            ——            ——            ——      ——            ——      ——            ——  non-finished            ——
# Peer 17    50.8  non-finished            ——            ——     3.4          33.9      ——           4.3           4.8            ——
# Peer 18      ——            ——            ——            ——      ——            ——      ——            ——          14.5  non-finished
# Peer 19      ——           3.0            ——          12.6      ——            ——      ——            ——            ——            ——
#
# Total Finished Time for Each Peer:
# Peer 0: non-finished
# Peer 1: non-finished
# Peer 2: non-finished
# Peer 3: non-finished
# Peer 4: 68.7
# Peer 5: non-finished
# Peer 6: non-finished
# Peer 7: non-finished
# Peer 8: 81.3
# Peer 9: 61.0
# Peer 10: 93.7
# Peer 11: 10.1
# Peer 12: 60.1
# Peer 13: non-finished
# Peer 14: non-finished
# Peer 15: non-finished
# Peer 16: non-finished
# Peer 17: non-finished
# Peer 18: non-finished
# Peer 19: 12.6
#
#
# Peer 0: Average download time = 15.08
# Peer 1: Average download time = 6.98
# Peer 2: Average download time = 19.09
# Peer 3: Average download time = 11.57
# Peer 4: Average download time = 37.58
# Peer 5: Average download time = 7.15
# Peer 6: Average download time = 6.34
# Peer 7: No pieces downloaded.
# Peer 8: Average download time = 36.64
# Peer 9: Average download time = 34.43
# Peer 10: Average download time = 63.57
# Peer 11: Average download time = 10.10
# Peer 12: Average download time = 24.50
# Peer 13: Average download time = 22.87
# Peer 14: Average download time = 34.60
# Peer 15: Average download time = 37.29
# Peer 16: No pieces downloaded.
# Peer 17: Average download time = 19.44
# Peer 18: Average download time = 14.50
# Peer 19: Average download time = 7.80
# Animation generation is disabled.

# %%
# 运行模拟并计算结果
num_simulations = 300
num_peers = 10
final_combined_averages = calculate_combined_averages(num_simulations, num_peers)

# 打印结果
print("Final Combined Averages for Request Strategies and Bandwidth Strategies:")
for request_strategy_name, strategies in final_combined_averages.items():
    print(f"\nRequest Strategy: {request_strategy_name}")
    for strategy, avg_time in strategies.items():
        print(f"  {strategy}: {avg_time:.2f} units" if avg_time is not None else f"  {strategy}: No data")
# Out:
# Final Combined Averages for Request Strategies and Bandwidth Strategies:
#
# Request Strategy: random_peer_selection
#   random_bandwidth: 17.46 units
#   tit_for_tat: 17.10 units
#   equal_distribution_strategy: 17.70 units
#   demand_priority: 18.18 units
#   free_rider_strategy: 20.16 units
#
# Request Strategy: avoid_excessive_requests
#   random_bandwidth: 13.35 units
#   tit_for_tat: 13.92 units
#   equal_distribution_strategy: 12.45 units
#   demand_priority: 12.97 units
#   free_rider_strategy: 15.67 units
