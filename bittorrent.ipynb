# %%
# !pip install simpy
# Out:
# Collecting simpy
#   Downloading simpy-4.1.1-py3-none-any.whl.metadata (6.1 kB)
# Downloading simpy-4.1.1-py3-none-any.whl (27 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.1.1

# %%
import simpy
import random
import statistics

# %%
def get_user_input():
    num_leecher = input("Input # of Leecher working: ")
    num_seeder = input("Input # of seeder working: ")

    params = [num_leecher, num_seeder]
    if all(str(i).isdigit() for i in params):  # Check input is valid
        params = [int(x) for x in params]
    else:
        print(
            "Could not parse input. Simulation will use default values:",
            "\n1 cashier, 1 server, 1 usher.",
        )
        params = [1, 1]
    return params

# %%
class bittorentNetwork(object):
    def __init__(self, env, num_leecher):
      self.env = env
      self.leecher = simpy.Resource(env, num_leecher)

# %%
TOTAL_PIECES = 10  # 总共的文件块数 / Total number of file pieces
SIMULATION_TIME = 100  # 模拟的总时长 / Total simulation time

class Peer:
    def __init__(self, env, id, upload_speed, download_speed):
        self.env = env
        self.id = id
        self.upload_speed = upload_speed  # 上传带宽 / Upload bandwidth
        self.download_speed = download_speed  # 下载带宽 / Download bandwidth
        self.file_pieces = set()  # 当前拥有的文件块 / File pieces currently owned
        self.peers = []  # 其他对等节点 / Other peers
        self.upload_resource = simpy.Resource(env, capacity=upload_speed)  # 上传带宽作为资源 / Upload bandwidth as a resource
        self.current_requests = 0  # 当前的请求数 / Current number of requests
        self.env.process(self.run())

    def add_peer(self, peer):
        self.peers.append(peer)

    def request_piece(self, piece, target):
        """请求特定文件块并动态调整带宽 / Request a specific file piece and dynamically adjust bandwidth"""
        # 检查目标节点是否仍然拥有该文件块 / Check if the target peer still has the requested file piece
        if piece in target.file_pieces:
            print(f'Time {self.env.now}: Peer {self.id} requests file piece {piece} from Peer {target.id}')

            # 请求目标节点的上传带宽资源 / Request the target peer's upload bandwidth resource
            with target.upload_resource.request() as req:
                # yield req
                # 等待资源可用 / Wait until the resource is available
                # 在下载开始时增加目标节点的请求数 / Increase the target peer's request count at the start of download
                target.current_requests += 1

                # 文件块大小 / Size of file piece
                piece_size = Peer.piece_size  # 假设每个文件块大小为 1 / Assume each file piece size is 1
                downloaded = 0  # 初始化已下载部分 / Initialize downloaded portion

                # 以较小的时间步进行下载，动态调整带宽 / Download the piece in smaller steps, adjusting bandwidth dynamically
                while downloaded < piece_size:
                    # 当前的请求数（可能动态变化） / Current number of requests (may change dynamically)
                    number_of_requests = target.current_requests

                    # 计算每个请求的可用带宽 / Calculate available bandwidth per request
                    available_bandwidth_per_request = target.upload_speed / max(1, number_of_requests)

                    # 每个时间步下载的数据量 / Amount of data downloaded per time step
                    data_per_step = available_bandwidth_per_request * 0.1  # 假设时间步为 0.1 秒 / Assume time step is 0.1 seconds

                    # 增加已下载的数据量 / Increase downloaded data
                    downloaded += data_per_step

                    # 模拟时间步 / Simulate the time step
                    yield self.env.timeout(0.1)

                    # 输出下载进度 / Print download progress
                    progress_percentage = (downloaded / piece_size) * 100
                    print(f'Time {self.env.now:.1f}: Peer {self.id} has downloaded {progress_percentage:.1f}% of file piece {piece}')
                # 下载完成后减少目标节点的请求数 / Decrease the target peer's request count after download
                target.current_requests -= 1

                # 下载完成后添加文件块 / Add the completed file piece to the owned set
                self.file_pieces.add(piece)
                print(f'Time {self.env.now:.1f}: Peer {self.id} completed download of file piece {piece}')
        else:
            # 目标节点已经没有这个文件块 / Target peer no longer has the file piece
            print(f"Time {self.env.now:.1f}: Peer {self.id} found that Peer {target.id} no longer has file piece {piece}")

    def run(self):
        while True:
            # 如果所有文件块已下载，停止请求 / Stop requesting if all file pieces are downloaded
            if len(self.file_pieces) == TOTAL_PIECES:
                print(f'Peer {self.id} has completed downloading all file pieces, stopping requests')
                break

            yield self.env.timeout(1)  # 每个时间步执行一次 / Execute once per time step

            # 查找当前节点缺少的文件块 / Find the file pieces that the current peer is missing
            missing_pieces = set(range(TOTAL_PIECES)) - self.file_pieces
            if not missing_pieces:
                break

            # 创建一个并行任务的列表 / Create a list of parallel tasks
            request_tasks = []

            # 创建一个"正在请求的文件块"集合，避免重复请求 / Create a set of "file pieces being requested" to avoid duplicate requests
            requesting_pieces = set()

            # 遍历每个缺少的文件块，找到拥有该文件块的对等节点 / Iterate over each missing file piece and find peers that have it
            for piece in missing_pieces:
                # 如果该块已经被请求，则跳过 / Skip if this piece is already being requested
                if piece in requesting_pieces:
                    continue
                shuffled_peers = self.peers[:]
                random.shuffle(shuffled_peers)  # 我把shuffle放在这里，因为我不想让id小的peer有更高的请求优先级 / I put shuffle here because I don't want peers with small IDs to have higher request priority

                # 遍历打乱后的节点顺序 / Iterate over shuffled peers
                for target_peer in shuffled_peers:
                    if piece in target_peer.file_pieces:
                        # 找到拥有该块的对等节点后，发起请求 / Once a peer with the piece is found, request it
                        request_tasks.append(self.env.process(self.request_piece(piece, target_peer)))

                        # 将该文件块加入到"正在请求的文件块"集合中 / Add the piece to the "requesting pieces" set
                        requesting_pieces.add(piece)

                        break  # 找到一个目标后退出该块的搜索 / Exit the loop for this piece once a peer is found

            # 并行处理多个请求 / Process all parallel requests
            if request_tasks:
                yield self.env.all_of(request_tasks)  # 并行执行所有请求任务 / Execute all request tasks in parallel

# %%
def run_simulation(num_peers):
    env = simpy.Environment()
    peers = []
    Peer.file_size = random.uniform(50, 200)  # Assume file size is between 50MB and 200MB
    Peer.piece_size = Peer.file_size / TOTAL_PIECES
    # 创建多个对等节点
    for i in range(num_peers):
        upload_speed = random.uniform(1, 5)  # 随机上传带宽
        download_speed = random.uniform(1, 5)  # 随机下载带宽
        peer = Peer(env, i, upload_speed, download_speed)
        peers.append(peer)
 # Randomly assign file pieces to each peer (0 to 9 pieces)
        #if i == num_peers-1:
        if i == 0:
            # The first peer is the seeder, owning all pieces
            peer.file_pieces = set(range(TOTAL_PIECES))
        else:
            # Other peers get a random number of pieces
            num_pieces = random.randint(0, TOTAL_PIECES - 1)  # Random number of pieces from 0 to 9
            peer.file_pieces = set(random.sample(range(TOTAL_PIECES), num_pieces))

        peers.append(peer)

    # 连接所有对等节点
    for peer in peers:
        for other_peer in peers:
            if peer != other_peer:
                peer.add_peer(other_peer)


    # 第一个节点拥有所有文件块，作为种子节点
    # peers[0].file_pieces = set(range(TOTAL_PIECES))
    # print(f'Peer 0 是种子节点，拥有所有文件块: {peers[0].file_pieces}')

    # 运行模拟
    env.run(until=SIMULATION_TIME)

# 运行模拟
run_simulation(5)  # 创建5个对等节点
# Out:
# Streaming output truncated to the last 5000 lines.
# Time 14.7: Peer 2 has downloaded 39.4% of file piece 1
# Time 14.7: Peer 2 has downloaded 39.0% of file piece 3
# Time 14.7: Peer 2 has downloaded 27.5% of file piece 4
# Time 14.7: Peer 2 has downloaded 38.8% of file piece 5
# Time 14.7: Peer 2 has downloaded 63.3% of file piece 7
# Time 14.7: Peer 2 has downloaded 62.2% of file piece 8
# Time 14.7: Peer 3 has downloaded 38.7% of file piece 0
# Time 14.7: Peer 3 has downloaded 38.6% of file piece 1
# Time 14.7: Peer 3 has downloaded 27.2% of file piece 2
# Time 14.7: Peer 3 has downloaded 61.8% of file piece 3
# Time 14.7: Peer 3 has downloaded 27.1% of file piece 4
# Time 14.7: Peer 3 has downloaded 38.5% of file piece 5
# Time 14.7: Peer 3 has downloaded 38.5% of file piece 6
# Time 14.7: Peer 3 has downloaded 61.6% of file piece 7
# Time 14.7: Peer 3 has downloaded 61.5% of file piece 9
# Time 14.7: Peer 4 has downloaded 27.1% of file piece 0
# Time 14.7: Peer 4 has downloaded 38.5% of file piece 1
# Time 14.7: Peer 4 has downloaded 27.0% of file piece 4
# Time 14.7: Peer 4 has downloaded 27.0% of file piece 5
# Time 14.8: Peer 1 has downloaded 28.4% of file piece 8
# Time 14.8: Peer 2 has downloaded 41.0% of file piece 0
# Time 14.8: Peer 2 has downloaded 39.7% of file piece 1
# Time 14.8: Peer 2 has downloaded 39.3% of file piece 3
# Time 14.8: Peer 2 has downloaded 27.7% of file piece 4
# Time 14.8: Peer 2 has downloaded 39.1% of file piece 5
# Time 14.8: Peer 2 has downloaded 63.8% of file piece 7
# Time 14.8: Peer 2 has downloaded 62.7% of file piece 8
# Time 14.8: Peer 3 has downloaded 39.0% of file piece 0
# Time 14.8: Peer 3 has downloaded 38.9% of file piece 1
# Time 14.8: Peer 3 has downloaded 27.4% of file piece 2
# Time 14.8: Peer 3 has downloaded 62.3% of file piece 3
# Time 14.8: Peer 3 has downloaded 27.3% of file piece 4
# Time 14.8: Peer 3 has downloaded 38.8% of file piece 5
# Time 14.8: Peer 3 has downloaded 38.8% of file piece 6
# Time 14.8: Peer 3 has downloaded 62.1% of file piece 7
# Time 14.8: Peer 3 has downloaded 62.0% of file piece 9
# Time 14.8: Peer 4 has downloaded 27.3% of file piece 0
# Time 14.8: Peer 4 has downloaded 38.7% of file piece 1
# Time 14.8: Peer 4 has downloaded 27.2% of file piece 4
# Time 14.8: Peer 4 has downloaded 27.2% of file piece 5
# Time 14.9: Peer 1 has downloaded 28.6% of file piece 8
# Time 14.9: Peer 2 has downloaded 41.3% of file piece 0
# Time 14.9: Peer 2 has downloaded 40.0% of file piece 1
# Time 14.9: Peer 2 has downloaded 39.6% of file piece 3
# Time 14.9: Peer 2 has downloaded 27.9% of file piece 4
# Time 14.9: Peer 2 has downloaded 39.4% of file piece 5
# Time 14.9: Peer 2 has downloaded 64.2% of file piece 7
# Time 14.9: Peer 2 has downloaded 63.1% of file piece 8
# Time 14.9: Peer 3 has downloaded 39.2% of file piece 0
# Time 14.9: Peer 3 has downloaded 39.2% of file piece 1
# Time 14.9: Peer 3 has downloaded 27.6% of file piece 2
# Time 14.9: Peer 3 has downloaded 62.7% of file piece 3
# Time 14.9: Peer 3 has downloaded 27.5% of file piece 4
# Time 14.9: Peer 3 has downloaded 39.1% of file piece 5
# Time 14.9: Peer 3 has downloaded 39.1% of file piece 6
# Time 14.9: Peer 3 has downloaded 62.5% of file piece 7
# Time 14.9: Peer 3 has downloaded 62.4% of file piece 9
# Time 14.9: Peer 4 has downloaded 27.5% of file piece 0
# Time 14.9: Peer 4 has downloaded 39.0% of file piece 1
# Time 14.9: Peer 4 has downloaded 27.4% of file piece 4
# Time 14.9: Peer 4 has downloaded 27.4% of file piece 5
# Time 15.0: Peer 1 has downloaded 28.8% of file piece 8
# Time 15.0: Peer 2 has downloaded 41.5% of file piece 0
# Time 15.0: Peer 2 has downloaded 40.3% of file piece 1
# Time 15.0: Peer 2 has downloaded 39.9% of file piece 3
# Time 15.0: Peer 2 has downloaded 28.1% of file piece 4
# Time 15.0: Peer 2 has downloaded 39.7% of file piece 5
# Time 15.0: Peer 2 has downloaded 64.7% of file piece 7
# Time 15.0: Peer 2 has downloaded 63.6% of file piece 8
# Time 15.0: Peer 3 has downloaded 39.5% of file piece 0
# Time 15.0: Peer 3 has downloaded 39.4% of file piece 1
# Time 15.0: Peer 3 has downloaded 27.8% of file piece 2
# Time 15.0: Peer 3 has downloaded 63.2% of file piece 3
# Time 15.0: Peer 3 has downloaded 27.7% of file piece 4
# Time 15.0: Peer 3 has downloaded 39.4% of file piece 5
# Time 15.0: Peer 3 has downloaded 39.3% of file piece 6
# Time 15.0: Peer 3 has downloaded 63.0% of file piece 7
# Time 15.0: Peer 3 has downloaded 62.9% of file piece 9
# Time 15.0: Peer 4 has downloaded 27.7% of file piece 0
# Time 15.0: Peer 4 has downloaded 39.3% of file piece 1
# Time 15.0: Peer 4 has downloaded 27.6% of file piece 4
# Time 15.0: Peer 4 has downloaded 27.6% of file piece 5
# Time 15.1: Peer 1 has downloaded 29.0% of file piece 8
# Time 15.1: Peer 2 has downloaded 41.8% of file piece 0
# Time 15.1: Peer 2 has downloaded 40.6% of file piece 1
# Time 15.1: Peer 2 has downloaded 40.1% of file piece 3
# Time 15.1: Peer 2 has downloaded 28.3% of file piece 4
# Time 15.1: Peer 2 has downloaded 39.9% of file piece 5
# Time 15.1: Peer 2 has downloaded 65.1% of file piece 7
# Time 15.1: Peer 2 has downloaded 64.0% of file piece 8
# Time 15.1: Peer 3 has downloaded 39.8% of file piece 0
# Time 15.1: Peer 3 has downloaded 39.7% of file piece 1
# Time 15.1: Peer 3 has downloaded 28.0% of file piece 2
# Time 15.1: Peer 3 has downloaded 63.6% of file piece 3
# Time 15.1: Peer 3 has downloaded 27.9% of file piece 4
# Time 15.1: Peer 3 has downloaded 39.7% of file piece 5
# Time 15.1: Peer 3 has downloaded 39.6% of file piece 6
# Time 15.1: Peer 3 has downloaded 63.4% of file piece 7
# Time 15.1: Peer 3 has downloaded 63.3% of file piece 9
# Time 15.1: Peer 4 has downloaded 27.9% of file piece 0
# Time 15.1: Peer 4 has downloaded 39.6% of file piece 1
# Time 15.1: Peer 4 has downloaded 27.8% of file piece 4
# Time 15.1: Peer 4 has downloaded 27.8% of file piece 5
# Time 15.2: Peer 1 has downloaded 29.2% of file piece 8
# Time 15.2: Peer 2 has downloaded 42.1% of file piece 0
# Time 15.2: Peer 2 has downloaded 40.8% of file piece 1
# Time 15.2: Peer 2 has downloaded 40.4% of file piece 3
# Time 15.2: Peer 2 has downloaded 28.5% of file piece 4
# Time 15.2: Peer 2 has downloaded 40.2% of file piece 5
# Time 15.2: Peer 2 has downloaded 65.6% of file piece 7
# Time 15.2: Peer 2 has downloaded 64.5% of file piece 8
# Time 15.2: Peer 3 has downloaded 40.1% of file piece 0
# Time 15.2: Peer 3 has downloaded 40.0% of file piece 1
# Time 15.2: Peer 3 has downloaded 28.2% of file piece 2
# Time 15.2: Peer 3 has downloaded 64.1% of file piece 3
# Time 15.2: Peer 3 has downloaded 28.1% of file piece 4
# Time 15.2: Peer 3 has downloaded 39.9% of file piece 5
# Time 15.2: Peer 3 has downloaded 39.9% of file piece 6
# Time 15.2: Peer 3 has downloaded 63.9% of file piece 7
# Time 15.2: Peer 3 has downloaded 63.8% of file piece 9
# Time 15.2: Peer 4 has downloaded 28.0% of file piece 0
# Time 15.2: Peer 4 has downloaded 39.9% of file piece 1
# Time 15.2: Peer 4 has downloaded 28.0% of file piece 4
# Time 15.2: Peer 4 has downloaded 28.0% of file piece 5
# Time 15.3: Peer 1 has downloaded 29.3% of file piece 8
# Time 15.3: Peer 2 has downloaded 42.4% of file piece 0
# Time 15.3: Peer 2 has downloaded 41.1% of file piece 1
# Time 15.3: Peer 2 has downloaded 40.7% of file piece 3
# Time 15.3: Peer 2 has downloaded 28.7% of file piece 4
# Time 15.3: Peer 2 has downloaded 40.5% of file piece 5
# Time 15.3: Peer 2 has downloaded 66.0% of file piece 7
# Time 15.3: Peer 2 has downloaded 64.9% of file piece 8
# Time 15.3: Peer 3 has downloaded 40.4% of file piece 0
# Time 15.3: Peer 3 has downloaded 40.3% of file piece 1
# Time 15.3: Peer 3 has downloaded 28.4% of file piece 2
# Time 15.3: Peer 3 has downloaded 64.5% of file piece 3
# Time 15.3: Peer 3 has downloaded 28.3% of file piece 4
# Time 15.3: Peer 3 has downloaded 40.2% of file piece 5
# Time 15.3: Peer 3 has downloaded 40.2% of file piece 6
# Time 15.3: Peer 3 has downloaded 64.3% of file piece 7
# Time 15.3: Peer 3 has downloaded 64.2% of file piece 9
# Time 15.3: Peer 4 has downloaded 28.2% of file piece 0
# Time 15.3: Peer 4 has downloaded 40.1% of file piece 1
# Time 15.3: Peer 4 has downloaded 28.2% of file piece 4
# Time 15.3: Peer 4 has downloaded 28.2% of file piece 5
# Time 15.4: Peer 1 has downloaded 29.5% of file piece 8
# Time 15.4: Peer 2 has downloaded 42.7% of file piece 0
# Time 15.4: Peer 2 has downloaded 41.4% of file piece 1
# Time 15.4: Peer 2 has downloaded 41.0% of file piece 3
# Time 15.4: Peer 2 has downloaded 28.9% of file piece 4
# Time 15.4: Peer 2 has downloaded 40.8% of file piece 5
# Time 15.4: Peer 2 has downloaded 66.5% of file piece 7
# Time 15.4: Peer 2 has downloaded 65.4% of file piece 8
# Time 15.4: Peer 3 has downloaded 40.6% of file piece 0
# Time 15.4: Peer 3 has downloaded 40.6% of file piece 1
# Time 15.4: Peer 3 has downloaded 28.6% of file piece 2
# Time 15.4: Peer 3 has downloaded 65.0% of file piece 3
# Time 15.4: Peer 3 has downloaded 28.5% of file piece 4
# Time 15.4: Peer 3 has downloaded 40.5% of file piece 5
# Time 15.4: Peer 3 has downloaded 40.5% of file piece 6
# Time 15.4: Peer 3 has downloaded 64.8% of file piece 7
# Time 15.4: Peer 3 has downloaded 64.7% of file piece 9
# Time 15.4: Peer 4 has downloaded 28.4% of file piece 0
# Time 15.4: Peer 4 has downloaded 40.4% of file piece 1
# Time 15.4: Peer 4 has downloaded 28.4% of file piece 4
# Time 15.4: Peer 4 has downloaded 28.4% of file piece 5
# Time 15.5: Peer 1 has downloaded 29.7% of file piece 8
# Time 15.5: Peer 2 has downloaded 42.9% of file piece 0
# Time 15.5: Peer 2 has downloaded 41.7% of file piece 1
# Time 15.5: Peer 2 has downloaded 41.3% of file piece 3
# Time 15.5: Peer 2 has downloaded 29.1% of file piece 4
# Time 15.5: Peer 2 has downloaded 41.1% of file piece 5
# Time 15.5: Peer 2 has downloaded 66.9% of file piece 7
# Time 15.5: Peer 2 has downloaded 65.8% of file piece 8
# Time 15.5: Peer 3 has downloaded 40.9% of file piece 0
# Time 15.5: Peer 3 has downloaded 40.8% of file piece 1
# Time 15.5: Peer 3 has downloaded 28.8% of file piece 2
# Time 15.5: Peer 3 has downloaded 65.4% of file piece 3
# Time 15.5: Peer 3 has downloaded 28.7% of file piece 4
# Time 15.5: Peer 3 has downloaded 40.8% of file piece 5
# Time 15.5: Peer 3 has downloaded 40.7% of file piece 6
# Time 15.5: Peer 3 has downloaded 65.2% of file piece 7
# Time 15.5: Peer 3 has downloaded 65.1% of file piece 9
# Time 15.5: Peer 4 has downloaded 28.6% of file piece 0
# Time 15.5: Peer 4 has downloaded 40.7% of file piece 1
# Time 15.5: Peer 4 has downloaded 28.6% of file piece 4
# Time 15.5: Peer 4 has downloaded 28.6% of file piece 5
# Time 15.6: Peer 1 has downloaded 29.9% of file piece 8
# Time 15.6: Peer 2 has downloaded 43.2% of file piece 0
# Time 15.6: Peer 2 has downloaded 42.0% of file piece 1
# Time 15.6: Peer 2 has downloaded 41.5% of file piece 3
# Time 15.6: Peer 2 has downloaded 29.2% of file piece 4
# Time 15.6: Peer 2 has downloaded 41.3% of file piece 5
# Time 15.6: Peer 2 has downloaded 67.4% of file piece 7
# Time 15.6: Peer 2 has downloaded 66.3% of file piece 8
# Time 15.6: Peer 3 has downloaded 41.2% of file piece 0
# Time 15.6: Peer 3 has downloaded 41.1% of file piece 1
# Time 15.6: Peer 3 has downloaded 29.0% of file piece 2
# Time 15.6: Peer 3 has downloaded 65.9% of file piece 3
# Time 15.6: Peer 3 has downloaded 28.9% of file piece 4
# Time 15.6: Peer 3 has downloaded 41.1% of file piece 5
# Time 15.6: Peer 3 has downloaded 41.0% of file piece 6
# Time 15.6: Peer 3 has downloaded 65.7% of file piece 7
# Time 15.6: Peer 3 has downloaded 65.6% of file piece 9
# Time 15.6: Peer 4 has downloaded 28.8% of file piece 0
# Time 15.6: Peer 4 has downloaded 41.0% of file piece 1
# Time 15.6: Peer 4 has downloaded 28.8% of file piece 4
# Time 15.6: Peer 4 has downloaded 28.8% of file piece 5
# Time 15.7: Peer 1 has downloaded 30.1% of file piece 8
# Time 15.7: Peer 2 has downloaded 43.5% of file piece 0
# Time 15.7: Peer 2 has downloaded 42.2% of file piece 1
# Time 15.7: Peer 2 has downloaded 41.8% of file piece 3
# Time 15.7: Peer 2 has downloaded 29.4% of file piece 4
# Time 15.7: Peer 2 has downloaded 41.6% of file piece 5
# Time 15.7: Peer 2 has downloaded 67.8% of file piece 7
# Time 15.7: Peer 2 has downloaded 66.7% of file piece 8
# Time 15.7: Peer 3 has downloaded 41.5% of file piece 0
# Time 15.7: Peer 3 has downloaded 41.4% of file piece 1
# Time 15.7: Peer 3 has downloaded 29.2% of file piece 2
# Time 15.7: Peer 3 has downloaded 66.3% of file piece 3
# Time 15.7: Peer 3 has downloaded 29.1% of file piece 4
# Time 15.7: Peer 3 has downloaded 41.3% of file piece 5
# Time 15.7: Peer 3 has downloaded 41.3% of file piece 6
# Time 15.7: Peer 3 has downloaded 66.1% of file piece 7
# Time 15.7: Peer 3 has downloaded 66.0% of file piece 9
# Time 15.7: Peer 4 has downloaded 29.0% of file piece 0
# Time 15.7: Peer 4 has downloaded 41.3% of file piece 1
# Time 15.7: Peer 4 has downloaded 29.0% of file piece 4
# Time 15.7: Peer 4 has downloaded 29.0% of file piece 5
# Time 15.8: Peer 1 has downloaded 30.3% of file piece 8
# Time 15.8: Peer 2 has downloaded 43.8% of file piece 0
# Time 15.8: Peer 2 has downloaded 42.5% of file piece 1
# Time 15.8: Peer 2 has downloaded 42.1% of file piece 3
# Time 15.8: Peer 2 has downloaded 29.6% of file piece 4
# Time 15.8: Peer 2 has downloaded 41.9% of file piece 5
# Time 15.8: Peer 2 has downloaded 68.3% of file piece 7
# Time 15.8: Peer 2 has downloaded 67.1% of file piece 8
# Time 15.8: Peer 3 has downloaded 41.8% of file piece 0
# Time 15.8: Peer 3 has downloaded 41.7% of file piece 1
# Time 15.8: Peer 3 has downloaded 29.4% of file piece 2
# Time 15.8: Peer 3 has downloaded 66.8% of file piece 3
# Time 15.8: Peer 3 has downloaded 29.3% of file piece 4
# Time 15.8: Peer 3 has downloaded 41.6% of file piece 5
# Time 15.8: Peer 3 has downloaded 41.6% of file piece 6
# Time 15.8: Peer 3 has downloaded 66.6% of file piece 7
# Time 15.8: Peer 3 has downloaded 66.5% of file piece 9
# Time 15.8: Peer 4 has downloaded 29.2% of file piece 0
# Time 15.8: Peer 4 has downloaded 41.5% of file piece 1
# Time 15.8: Peer 4 has downloaded 29.2% of file piece 4
# Time 15.8: Peer 4 has downloaded 29.2% of file piece 5
# Time 15.9: Peer 1 has downloaded 30.5% of file piece 8
# Time 15.9: Peer 2 has downloaded 44.1% of file piece 0
# Time 15.9: Peer 2 has downloaded 42.8% of file piece 1
# Time 15.9: Peer 2 has downloaded 42.4% of file piece 3
# Time 15.9: Peer 2 has downloaded 29.8% of file piece 4
# Time 15.9: Peer 2 has downloaded 42.2% of file piece 5
# Time 15.9: Peer 2 has downloaded 68.7% of file piece 7
# Time 15.9: Peer 2 has downloaded 67.6% of file piece 8
# Time 15.9: Peer 3 has downloaded 42.1% of file piece 0
# Time 15.9: Peer 3 has downloaded 42.0% of file piece 1
# Time 15.9: Peer 3 has downloaded 29.6% of file piece 2
# Time 15.9: Peer 3 has downloaded 67.2% of file piece 3
# Time 15.9: Peer 3 has downloaded 29.5% of file piece 4
# Time 15.9: Peer 3 has downloaded 41.9% of file piece 5
# Time 15.9: Peer 3 has downloaded 41.9% of file piece 6
# Time 15.9: Peer 3 has downloaded 67.0% of file piece 7
# Time 15.9: Peer 3 has downloaded 66.9% of file piece 9
# Time 15.9: Peer 4 has downloaded 29.4% of file piece 0
# Time 15.9: Peer 4 has downloaded 41.8% of file piece 1
# Time 15.9: Peer 4 has downloaded 29.4% of file piece 4
# Time 15.9: Peer 4 has downloaded 29.3% of file piece 5
# Time 16.0: Peer 1 has downloaded 30.7% of file piece 8
# Time 16.0: Peer 2 has downloaded 44.4% of file piece 0
# Time 16.0: Peer 2 has downloaded 43.1% of file piece 1
# Time 16.0: Peer 2 has downloaded 42.7% of file piece 3
# Time 16.0: Peer 2 has downloaded 30.0% of file piece 4
# Time 16.0: Peer 2 has downloaded 42.5% of file piece 5
# Time 16.0: Peer 2 has downloaded 69.2% of file piece 7
# Time 16.0: Peer 2 has downloaded 68.0% of file piece 8
# Time 16.0: Peer 3 has downloaded 42.3% of file piece 0
# Time 16.0: Peer 3 has downloaded 42.2% of file piece 1
# Time 16.0: Peer 3 has downloaded 29.8% of file piece 2
# Time 16.0: Peer 3 has downloaded 67.7% of file piece 3
# Time 16.0: Peer 3 has downloaded 29.7% of file piece 4
# Time 16.0: Peer 3 has downloaded 42.2% of file piece 5
# Time 16.0: Peer 3 has downloaded 42.1% of file piece 6
# Time 16.0: Peer 3 has downloaded 67.5% of file piece 7
# Time 16.0: Peer 3 has downloaded 67.4% of file piece 9
# Time 16.0: Peer 4 has downloaded 29.6% of file piece 0
# Time 16.0: Peer 4 has downloaded 42.1% of file piece 1
# Time 16.0: Peer 4 has downloaded 29.6% of file piece 4
# Time 16.0: Peer 4 has downloaded 29.5% of file piece 5
# Time 16.1: Peer 1 has downloaded 30.9% of file piece 8
# Time 16.1: Peer 2 has downloaded 44.6% of file piece 0
# Time 16.1: Peer 2 has downloaded 43.4% of file piece 1
# Time 16.1: Peer 2 has downloaded 42.9% of file piece 3
# Time 16.1: Peer 2 has downloaded 30.2% of file piece 4
# Time 16.1: Peer 2 has downloaded 42.7% of file piece 5
# Time 16.1: Peer 2 has downloaded 69.6% of file piece 7
# Time 16.1: Peer 2 has downloaded 68.5% of file piece 8
# Time 16.1: Peer 3 has downloaded 42.6% of file piece 0
# Time 16.1: Peer 3 has downloaded 42.5% of file piece 1
# Time 16.1: Peer 3 has downloaded 30.0% of file piece 2
# Time 16.1: Peer 3 has downloaded 68.1% of file piece 3
# Time 16.1: Peer 3 has downloaded 29.9% of file piece 4
# Time 16.1: Peer 3 has downloaded 42.5% of file piece 5
# Time 16.1: Peer 3 has downloaded 42.4% of file piece 6
# Time 16.1: Peer 3 has downloaded 67.9% of file piece 7
# Time 16.1: Peer 3 has downloaded 67.8% of file piece 9
# Time 16.1: Peer 4 has downloaded 29.8% of file piece 0
# Time 16.1: Peer 4 has downloaded 42.4% of file piece 1
# Time 16.1: Peer 4 has downloaded 29.8% of file piece 4
# Time 16.1: Peer 4 has downloaded 29.7% of file piece 5
# Time 16.2: Peer 1 has downloaded 31.1% of file piece 8
# Time 16.2: Peer 2 has downloaded 44.9% of file piece 0
# Time 16.2: Peer 2 has downloaded 43.7% of file piece 1
# Time 16.2: Peer 2 has downloaded 43.2% of file piece 3
# Time 16.2: Peer 2 has downloaded 30.4% of file piece 4
# Time 16.2: Peer 2 has downloaded 43.0% of file piece 5
# Time 16.2: Peer 2 has downloaded 70.1% of file piece 7
# Time 16.2: Peer 2 has downloaded 68.9% of file piece 8
# Time 16.2: Peer 3 has downloaded 42.9% of file piece 0
# Time 16.2: Peer 3 has downloaded 42.8% of file piece 1
# Time 16.2: Peer 3 has downloaded 30.2% of file piece 2
# Time 16.2: Peer 3 has downloaded 68.6% of file piece 3
# Time 16.2: Peer 3 has downloaded 30.1% of file piece 4
# Time 16.2: Peer 3 has downloaded 42.7% of file piece 5
# Time 16.2: Peer 3 has downloaded 42.7% of file piece 6
# Time 16.2: Peer 3 has downloaded 68.4% of file piece 7
# Time 16.2: Peer 3 has downloaded 68.3% of file piece 9
# Time 16.2: Peer 4 has downloaded 30.0% of file piece 0
# Time 16.2: Peer 4 has downloaded 42.7% of file piece 1
# Time 16.2: Peer 4 has downloaded 30.0% of file piece 4
# Time 16.2: Peer 4 has downloaded 29.9% of file piece 5
# Time 16.3: Peer 1 has downloaded 31.3% of file piece 8
# Time 16.3: Peer 2 has downloaded 45.2% of file piece 0
# Time 16.3: Peer 2 has downloaded 43.9% of file piece 1
# Time 16.3: Peer 2 has downloaded 43.5% of file piece 3
# Time 16.3: Peer 2 has downloaded 30.6% of file piece 4
# Time 16.3: Peer 2 has downloaded 43.3% of file piece 5
# Time 16.3: Peer 2 has downloaded 70.5% of file piece 7
# Time 16.3: Peer 2 has downloaded 69.4% of file piece 8
# Time 16.3: Peer 3 has downloaded 43.2% of file piece 0
# Time 16.3: Peer 3 has downloaded 43.1% of file piece 1
# Time 16.3: Peer 3 has downloaded 30.4% of file piece 2
# Time 16.3: Peer 3 has downloaded 69.0% of file piece 3
# Time 16.3: Peer 3 has downloaded 30.3% of file piece 4
# Time 16.3: Peer 3 has downloaded 43.0% of file piece 5
# Time 16.3: Peer 3 has downloaded 43.0% of file piece 6
# Time 16.3: Peer 3 has downloaded 68.8% of file piece 7
# Time 16.3: Peer 3 has downloaded 68.7% of file piece 9
# Time 16.3: Peer 4 has downloaded 30.2% of file piece 0
# Time 16.3: Peer 4 has downloaded 42.9% of file piece 1
# Time 16.3: Peer 4 has downloaded 30.2% of file piece 4
# Time 16.3: Peer 4 has downloaded 30.1% of file piece 5
# Time 16.4: Peer 1 has downloaded 31.5% of file piece 8
# Time 16.4: Peer 2 has downloaded 45.5% of file piece 0
# Time 16.4: Peer 2 has downloaded 44.2% of file piece 1
# Time 16.4: Peer 2 has downloaded 43.8% of file piece 3
# Time 16.4: Peer 2 has downloaded 30.8% of file piece 4
# Time 16.4: Peer 2 has downloaded 43.6% of file piece 5
# Time 16.4: Peer 2 has downloaded 71.0% of file piece 7
# Time 16.4: Peer 2 has downloaded 69.8% of file piece 8
# Time 16.4: Peer 3 has downloaded 43.5% of file piece 0
# Time 16.4: Peer 3 has downloaded 43.4% of file piece 1
# Time 16.4: Peer 3 has downloaded 30.6% of file piece 2
# Time 16.4: Peer 3 has downloaded 69.5% of file piece 3
# Time 16.4: Peer 3 has downloaded 30.5% of file piece 4
# Time 16.4: Peer 3 has downloaded 43.3% of file piece 5
# Time 16.4: Peer 3 has downloaded 43.3% of file piece 6
# Time 16.4: Peer 3 has downloaded 69.3% of file piece 7
# Time 16.4: Peer 3 has downloaded 69.2% of file piece 9
# Time 16.4: Peer 4 has downloaded 30.4% of file piece 0
# Time 16.4: Peer 4 has downloaded 43.2% of file piece 1
# Time 16.4: Peer 4 has downloaded 30.4% of file piece 4
# Time 16.4: Peer 4 has downloaded 30.3% of file piece 5
# Time 16.5: Peer 1 has downloaded 31.7% of file piece 8
# Time 16.5: Peer 2 has downloaded 45.8% of file piece 0
# Time 16.5: Peer 2 has downloaded 44.5% of file piece 1
# Time 16.5: Peer 2 has downloaded 44.1% of file piece 3
# Time 16.5: Peer 2 has downloaded 31.0% of file piece 4
# Time 16.5: Peer 2 has downloaded 43.9% of file piece 5
# Time 16.5: Peer 2 has downloaded 71.4% of file piece 7
# Time 16.5: Peer 2 has downloaded 70.3% of file piece 8
# Time 16.5: Peer 3 has downloaded 43.7% of file piece 0
# Time 16.5: Peer 3 has downloaded 43.7% of file piece 1
# Time 16.5: Peer 3 has downloaded 30.8% of file piece 2
# Time 16.5: Peer 3 has downloaded 69.9% of file piece 3
# Time 16.5: Peer 3 has downloaded 30.7% of file piece 4
# Time 16.5: Peer 3 has downloaded 43.6% of file piece 5
# Time 16.5: Peer 3 has downloaded 43.5% of file piece 6
# Time 16.5: Peer 3 has downloaded 69.7% of file piece 7
# Time 16.5: Peer 3 has downloaded 69.6% of file piece 9
# Time 16.5: Peer 4 has downloaded 30.6% of file piece 0
# Time 16.5: Peer 4 has downloaded 43.5% of file piece 1
# Time 16.5: Peer 4 has downloaded 30.6% of file piece 4
# Time 16.5: Peer 4 has downloaded 30.5% of file piece 5
# Time 16.6: Peer 1 has downloaded 31.9% of file piece 8
# Time 16.6: Peer 2 has downloaded 46.0% of file piece 0
# Time 16.6: Peer 2 has downloaded 44.8% of file piece 1
# Time 16.6: Peer 2 has downloaded 44.4% of file piece 3
# Time 16.6: Peer 2 has downloaded 31.2% of file piece 4
# Time 16.6: Peer 2 has downloaded 44.1% of file piece 5
# Time 16.6: Peer 2 has downloaded 71.9% of file piece 7
# Time 16.6: Peer 2 has downloaded 70.7% of file piece 8
# Time 16.6: Peer 3 has downloaded 44.0% of file piece 0
# Time 16.6: Peer 3 has downloaded 43.9% of file piece 1
# Time 16.6: Peer 3 has downloaded 31.0% of file piece 2
# Time 16.6: Peer 3 has downloaded 70.4% of file piece 3
# Time 16.6: Peer 3 has downloaded 30.9% of file piece 4
# Time 16.6: Peer 3 has downloaded 43.9% of file piece 5
# Time 16.6: Peer 3 has downloaded 43.8% of file piece 6
# Time 16.6: Peer 3 has downloaded 70.2% of file piece 7
# Time 16.6: Peer 3 has downloaded 70.1% of file piece 9
# Time 16.6: Peer 4 has downloaded 30.8% of file piece 0
# Time 16.6: Peer 4 has downloaded 43.8% of file piece 1
# Time 16.6: Peer 4 has downloaded 30.8% of file piece 4
# Time 16.6: Peer 4 has downloaded 30.7% of file piece 5
# Time 16.7: Peer 1 has downloaded 32.1% of file piece 8
# Time 16.7: Peer 2 has downloaded 46.3% of file piece 0
# Time 16.7: Peer 2 has downloaded 45.1% of file piece 1
# Time 16.7: Peer 2 has downloaded 44.6% of file piece 3
# Time 16.7: Peer 2 has downloaded 31.4% of file piece 4
# Time 16.7: Peer 2 has downloaded 44.4% of file piece 5
# Time 16.7: Peer 2 has downloaded 72.3% of file piece 7
# Time 16.7: Peer 2 has downloaded 71.2% of file piece 8
# Time 16.7: Peer 3 has downloaded 44.3% of file piece 0
# Time 16.7: Peer 3 has downloaded 44.2% of file piece 1
# Time 16.7: Peer 3 has downloaded 31.2% of file piece 2
# Time 16.7: Peer 3 has downloaded 70.8% of file piece 3
# Time 16.7: Peer 3 has downloaded 31.1% of file piece 4
# Time 16.7: Peer 3 has downloaded 44.2% of file piece 5
# Time 16.7: Peer 3 has downloaded 44.1% of file piece 6
# Time 16.7: Peer 3 has downloaded 70.6% of file piece 7
# Time 16.7: Peer 3 has downloaded 70.5% of file piece 9
# Time 16.7: Peer 4 has downloaded 31.0% of file piece 0
# Time 16.7: Peer 4 has downloaded 44.1% of file piece 1
# Time 16.7: Peer 4 has downloaded 31.0% of file piece 4
# Time 16.7: Peer 4 has downloaded 30.9% of file piece 5
# Time 16.8: Peer 1 has downloaded 32.3% of file piece 8
# Time 16.8: Peer 2 has downloaded 46.6% of file piece 0
# Time 16.8: Peer 2 has downloaded 45.3% of file piece 1
# Time 16.8: Peer 2 has downloaded 44.9% of file piece 3
# Time 16.8: Peer 2 has downloaded 31.6% of file piece 4
# Time 16.8: Peer 2 has downloaded 44.7% of file piece 5
# Time 16.8: Peer 2 has downloaded 72.8% of file piece 7
# Time 16.8: Peer 2 has downloaded 71.6% of file piece 8
# Time 16.8: Peer 3 has downloaded 44.6% of file piece 0
# Time 16.8: Peer 3 has downloaded 44.5% of file piece 1
# Time 16.8: Peer 3 has downloaded 31.4% of file piece 2
# Time 16.8: Peer 3 has downloaded 71.3% of file piece 3
# Time 16.8: Peer 3 has downloaded 31.3% of file piece 4
# Time 16.8: Peer 3 has downloaded 44.4% of file piece 5
# Time 16.8: Peer 3 has downloaded 44.4% of file piece 6
# Time 16.8: Peer 3 has downloaded 71.1% of file piece 7
# Time 16.8: Peer 3 has downloaded 71.0% of file piece 9
# Time 16.8: Peer 4 has downloaded 31.2% of file piece 0
# Time 16.8: Peer 4 has downloaded 44.4% of file piece 1
# Time 16.8: Peer 4 has downloaded 31.2% of file piece 4
# Time 16.8: Peer 4 has downloaded 31.1% of file piece 5
# Time 16.9: Peer 1 has downloaded 32.5% of file piece 8
# Time 16.9: Peer 2 has downloaded 46.9% of file piece 0
# Time 16.9: Peer 2 has downloaded 45.6% of file piece 1
# Time 16.9: Peer 2 has downloaded 45.2% of file piece 3
# Time 16.9: Peer 2 has downloaded 31.8% of file piece 4
# Time 16.9: Peer 2 has downloaded 45.0% of file piece 5
# Time 16.9: Peer 2 has downloaded 73.2% of file piece 7
# Time 16.9: Peer 2 has downloaded 72.1% of file piece 8
# Time 16.9: Peer 3 has downloaded 44.9% of file piece 0
# Time 16.9: Peer 3 has downloaded 44.8% of file piece 1
# Time 16.9: Peer 3 has downloaded 31.6% of file piece 2
# Time 16.9: Peer 3 has downloaded 71.7% of file piece 3
# Time 16.9: Peer 3 has downloaded 31.5% of file piece 4
# Time 16.9: Peer 3 has downloaded 44.7% of file piece 5
# Time 16.9: Peer 3 has downloaded 44.7% of file piece 6
# Time 16.9: Peer 3 has downloaded 71.5% of file piece 7
# Time 16.9: Peer 3 has downloaded 71.4% of file piece 9
# Time 16.9: Peer 4 has downloaded 31.4% of file piece 0
# Time 16.9: Peer 4 has downloaded 44.6% of file piece 1
# Time 16.9: Peer 4 has downloaded 31.4% of file piece 4
# Time 16.9: Peer 4 has downloaded 31.3% of file piece 5
# Time 17.0: Peer 1 has downloaded 32.7% of file piece 8
# Time 17.0: Peer 2 has downloaded 47.2% of file piece 0
# Time 17.0: Peer 2 has downloaded 45.9% of file piece 1
# Time 17.0: Peer 2 has downloaded 45.5% of file piece 3
# Time 17.0: Peer 2 has downloaded 32.0% of file piece 4
# Time 17.0: Peer 2 has downloaded 45.3% of file piece 5
# Time 17.0: Peer 2 has downloaded 73.7% of file piece 7
# Time 17.0: Peer 2 has downloaded 72.5% of file piece 8
# Time 17.0: Peer 3 has downloaded 45.1% of file piece 0
# Time 17.0: Peer 3 has downloaded 45.1% of file piece 1
# Time 17.0: Peer 3 has downloaded 31.8% of file piece 2
# Time 17.0: Peer 3 has downloaded 72.2% of file piece 3
# Time 17.0: Peer 3 has downloaded 31.7% of file piece 4
# Time 17.0: Peer 3 has downloaded 45.0% of file piece 5
# Time 17.0: Peer 3 has downloaded 45.0% of file piece 6
# Time 17.0: Peer 3 has downloaded 72.0% of file piece 7
# Time 17.0: Peer 3 has downloaded 71.9% of file piece 9
# Time 17.0: Peer 4 has downloaded 31.6% of file piece 0
# Time 17.0: Peer 4 has downloaded 44.9% of file piece 1
# Time 17.0: Peer 4 has downloaded 31.5% of file piece 4
# Time 17.0: Peer 4 has downloaded 31.5% of file piece 5
# Time 17.1: Peer 1 has downloaded 32.9% of file piece 8
# Time 17.1: Peer 2 has downloaded 47.4% of file piece 0
# Time 17.1: Peer 2 has downloaded 46.2% of file piece 1
# Time 17.1: Peer 2 has downloaded 45.8% of file piece 3
# Time 17.1: Peer 2 has downloaded 32.2% of file piece 4
# Time 17.1: Peer 2 has downloaded 45.5% of file piece 5
# Time 17.1: Peer 2 has downloaded 74.1% of file piece 7
# Time 17.1: Peer 2 has downloaded 73.0% of file piece 8
# Time 17.1: Peer 3 has downloaded 45.4% of file piece 0
# Time 17.1: Peer 3 has downloaded 45.3% of file piece 1
# Time 17.1: Peer 3 has downloaded 32.0% of file piece 2
# Time 17.1: Peer 3 has downloaded 72.6% of file piece 3
# Time 17.1: Peer 3 has downloaded 31.9% of file piece 4
# Time 17.1: Peer 3 has downloaded 45.3% of file piece 5
# Time 17.1: Peer 3 has downloaded 45.2% of file piece 6
# Time 17.1: Peer 3 has downloaded 72.4% of file piece 7
# Time 17.1: Peer 3 has downloaded 72.3% of file piece 9
# Time 17.1: Peer 4 has downloaded 31.8% of file piece 0
# Time 17.1: Peer 4 has downloaded 45.2% of file piece 1
# Time 17.1: Peer 4 has downloaded 31.7% of file piece 4
# Time 17.1: Peer 4 has downloaded 31.7% of file piece 5
# Time 17.2: Peer 1 has downloaded 33.1% of file piece 8
# Time 17.2: Peer 2 has downloaded 47.7% of file piece 0
# Time 17.2: Peer 2 has downloaded 46.5% of file piece 1
# Time 17.2: Peer 2 has downloaded 46.0% of file piece 3
# Time 17.2: Peer 2 has downloaded 32.4% of file piece 4
# Time 17.2: Peer 2 has downloaded 45.8% of file piece 5
# Time 17.2: Peer 2 has downloaded 74.6% of file piece 7
# Time 17.2: Peer 2 has downloaded 73.4% of file piece 8
# Time 17.2: Peer 3 has downloaded 45.7% of file piece 0
# Time 17.2: Peer 3 has downloaded 45.6% of file piece 1
# Time 17.2: Peer 3 has downloaded 32.2% of file piece 2
# Time 17.2: Peer 3 has downloaded 73.1% of file piece 3
# Time 17.2: Peer 3 has downloaded 32.1% of file piece 4
# Time 17.2: Peer 3 has downloaded 45.6% of file piece 5
# Time 17.2: Peer 3 has downloaded 45.5% of file piece 6
# Time 17.2: Peer 3 has downloaded 72.9% of file piece 7
# Time 17.2: Peer 3 has downloaded 72.8% of file piece 9
# Time 17.2: Peer 4 has downloaded 32.0% of file piece 0
# Time 17.2: Peer 4 has downloaded 45.5% of file piece 1
# Time 17.2: Peer 4 has downloaded 31.9% of file piece 4
# Time 17.2: Peer 4 has downloaded 31.9% of file piece 5
# Time 17.3: Peer 1 has downloaded 33.3% of file piece 8
# Time 17.3: Peer 2 has downloaded 48.0% of file piece 0
# Time 17.3: Peer 2 has downloaded 46.7% of file piece 1
# Time 17.3: Peer 2 has downloaded 46.3% of file piece 3
# Time 17.3: Peer 2 has downloaded 32.6% of file piece 4
# Time 17.3: Peer 2 has downloaded 46.1% of file piece 5
# Time 17.3: Peer 2 has downloaded 75.0% of file piece 7
# Time 17.3: Peer 2 has downloaded 73.9% of file piece 8
# Time 17.3: Peer 3 has downloaded 46.0% of file piece 0
# Time 17.3: Peer 3 has downloaded 45.9% of file piece 1
# Time 17.3: Peer 3 has downloaded 32.4% of file piece 2
# Time 17.3: Peer 3 has downloaded 73.5% of file piece 3
# Time 17.3: Peer 3 has downloaded 32.3% of file piece 4
# Time 17.3: Peer 3 has downloaded 45.8% of file piece 5
# Time 17.3: Peer 3 has downloaded 45.8% of file piece 6
# Time 17.3: Peer 3 has downloaded 73.3% of file piece 7
# Time 17.3: Peer 3 has downloaded 73.2% of file piece 9
# Time 17.3: Peer 4 has downloaded 32.2% of file piece 0
# Time 17.3: Peer 4 has downloaded 45.8% of file piece 1
# Time 17.3: Peer 4 has downloaded 32.1% of file piece 4
# Time 17.3: Peer 4 has downloaded 32.1% of file piece 5
# Time 17.4: Peer 1 has downloaded 33.5% of file piece 8
# Time 17.4: Peer 2 has downloaded 48.3% of file piece 0
# Time 17.4: Peer 2 has downloaded 47.0% of file piece 1
# Time 17.4: Peer 2 has downloaded 46.6% of file piece 3
# Time 17.4: Peer 2 has downloaded 32.8% of file piece 4
# Time 17.4: Peer 2 has downloaded 46.4% of file piece 5
# Time 17.4: Peer 2 has downloaded 75.5% of file piece 7
# Time 17.4: Peer 2 has downloaded 74.3% of file piece 8
# Time 17.4: Peer 3 has downloaded 46.3% of file piece 0
# Time 17.4: Peer 3 has downloaded 46.2% of file piece 1
# Time 17.4: Peer 3 has downloaded 32.6% of file piece 2
# Time 17.4: Peer 3 has downloaded 74.0% of file piece 3
# Time 17.4: Peer 3 has downloaded 32.5% of file piece 4
# Time 17.4: Peer 3 has downloaded 46.1% of file piece 5
# Time 17.4: Peer 3 has downloaded 46.1% of file piece 6
# Time 17.4: Peer 3 has downloaded 73.8% of file piece 7
# Time 17.4: Peer 3 has downloaded 73.7% of file piece 9
# Time 17.4: Peer 4 has downloaded 32.4% of file piece 0
# Time 17.4: Peer 4 has downloaded 46.0% of file piece 1
# Time 17.4: Peer 4 has downloaded 32.3% of file piece 4
# Time 17.4: Peer 4 has downloaded 32.3% of file piece 5
# Time 17.5: Peer 1 has downloaded 33.7% of file piece 8
# Time 17.5: Peer 2 has downloaded 48.6% of file piece 0
# Time 17.5: Peer 2 has downloaded 47.3% of file piece 1
# Time 17.5: Peer 2 has downloaded 46.9% of file piece 3
# Time 17.5: Peer 2 has downloaded 33.0% of file piece 4
# Time 17.5: Peer 2 has downloaded 46.7% of file piece 5
# Time 17.5: Peer 2 has downloaded 75.9% of file piece 7
# Time 17.5: Peer 2 has downloaded 74.8% of file piece 8
# Time 17.5: Peer 3 has downloaded 46.5% of file piece 0
# Time 17.5: Peer 3 has downloaded 46.5% of file piece 1
# Time 17.5: Peer 3 has downloaded 32.8% of file piece 2
# Time 17.5: Peer 3 has downloaded 74.4% of file piece 3
# Time 17.5: Peer 3 has downloaded 32.6% of file piece 4
# Time 17.5: Peer 3 has downloaded 46.4% of file piece 5
# Time 17.5: Peer 3 has downloaded 46.4% of file piece 6
# Time 17.5: Peer 3 has downloaded 74.2% of file piece 7
# Time 17.5: Peer 3 has downloaded 74.1% of file piece 9
# Time 17.5: Peer 4 has downloaded 32.6% of file piece 0
# Time 17.5: Peer 4 has downloaded 46.3% of file piece 1
# Time 17.5: Peer 4 has downloaded 32.5% of file piece 4
# Time 17.5: Peer 4 has downloaded 32.5% of file piece 5
# Time 17.6: Peer 1 has downloaded 33.9% of file piece 8
# Time 17.6: Peer 2 has downloaded 48.8% of file piece 0
# Time 17.6: Peer 2 has downloaded 47.6% of file piece 1
# Time 17.6: Peer 2 has downloaded 47.2% of file piece 3
# Time 17.6: Peer 2 has downloaded 33.2% of file piece 4
# Time 17.6: Peer 2 has downloaded 47.0% of file piece 5
# Time 17.6: Peer 2 has downloaded 76.4% of file piece 7
# Time 17.6: Peer 2 has downloaded 75.2% of file piece 8
# Time 17.6: Peer 3 has downloaded 46.8% of file piece 0
# Time 17.6: Peer 3 has downloaded 46.7% of file piece 1
# Time 17.6: Peer 3 has downloaded 33.0% of file piece 2
# Time 17.6: Peer 3 has downloaded 74.9% of file piece 3
# Time 17.6: Peer 3 has downloaded 32.8% of file piece 4
# Time 17.6: Peer 3 has downloaded 46.7% of file piece 5
# Time 17.6: Peer 3 has downloaded 46.6% of file piece 6
# Time 17.6: Peer 3 has downloaded 74.7% of file piece 7
# Time 17.6: Peer 3 has downloaded 74.6% of file piece 9
# Time 17.6: Peer 4 has downloaded 32.8% of file piece 0
# Time 17.6: Peer 4 has downloaded 46.6% of file piece 1
# Time 17.6: Peer 4 has downloaded 32.7% of file piece 4
# Time 17.6: Peer 4 has downloaded 32.7% of file piece 5
# Time 17.7: Peer 1 has downloaded 34.1% of file piece 8
# Time 17.7: Peer 2 has downloaded 49.1% of file piece 0
# Time 17.7: Peer 2 has downloaded 47.9% of file piece 1
# Time 17.7: Peer 2 has downloaded 47.4% of file piece 3
# Time 17.7: Peer 2 has downloaded 33.4% of file piece 4
# Time 17.7: Peer 2 has downloaded 47.2% of file piece 5
# Time 17.7: Peer 2 has downloaded 76.8% of file piece 7
# Time 17.7: Peer 2 has downloaded 75.7% of file piece 8
# Time 17.7: Peer 3 has downloaded 47.1% of file piece 0
# Time 17.7: Peer 3 has downloaded 47.0% of file piece 1
# Time 17.7: Peer 3 has downloaded 33.2% of file piece 2
# Time 17.7: Peer 3 has downloaded 75.3% of file piece 3
# Time 17.7: Peer 3 has downloaded 33.0% of file piece 4
# Time 17.7: Peer 3 has downloaded 47.0% of file piece 5
# Time 17.7: Peer 3 has downloaded 46.9% of file piece 6
# Time 17.7: Peer 3 has downloaded 75.1% of file piece 7
# Time 17.7: Peer 3 has downloaded 75.0% of file piece 9
# Time 17.7: Peer 4 has downloaded 33.0% of file piece 0
# Time 17.7: Peer 4 has downloaded 46.9% of file piece 1
# Time 17.7: Peer 4 has downloaded 32.9% of file piece 4
# Time 17.7: Peer 4 has downloaded 32.9% of file piece 5
# Time 17.8: Peer 1 has downloaded 34.3% of file piece 8
# Time 17.8: Peer 2 has downloaded 49.4% of file piece 0
# Time 17.8: Peer 2 has downloaded 48.1% of file piece 1
# Time 17.8: Peer 2 has downloaded 47.7% of file piece 3
# Time 17.8: Peer 2 has downloaded 33.6% of file piece 4
# Time 17.8: Peer 2 has downloaded 47.5% of file piece 5
# Time 17.8: Peer 2 has downloaded 77.3% of file piece 7
# Time 17.8: Peer 2 has downloaded 76.1% of file piece 8
# Time 17.8: Peer 3 has downloaded 47.4% of file piece 0
# Time 17.8: Peer 3 has downloaded 47.3% of file piece 1
# Time 17.8: Peer 3 has downloaded 33.4% of file piece 2
# Time 17.8: Peer 3 has downloaded 75.8% of file piece 3
# Time 17.8: Peer 3 has downloaded 33.2% of file piece 4
# Time 17.8: Peer 3 has downloaded 47.2% of file piece 5
# Time 17.8: Peer 3 has downloaded 47.2% of file piece 6
# Time 17.8: Peer 3 has downloaded 75.6% of file piece 7
# Time 17.8: Peer 3 has downloaded 75.5% of file piece 9
# Time 17.8: Peer 4 has downloaded 33.2% of file piece 0
# Time 17.8: Peer 4 has downloaded 47.2% of file piece 1
# Time 17.8: Peer 4 has downloaded 33.1% of file piece 4
# Time 17.8: Peer 4 has downloaded 33.1% of file piece 5
# Time 17.9: Peer 1 has downloaded 34.5% of file piece 8
# Time 17.9: Peer 2 has downloaded 49.7% of file piece 0
# Time 17.9: Peer 2 has downloaded 48.4% of file piece 1
# Time 17.9: Peer 2 has downloaded 48.0% of file piece 3
# Time 17.9: Peer 2 has downloaded 33.8% of file piece 4
# Time 17.9: Peer 2 has downloaded 47.8% of file piece 5
# Time 17.9: Peer 2 has downloaded 77.7% of file piece 7
# Time 17.9: Peer 2 has downloaded 76.6% of file piece 8
# Time 17.9: Peer 3 has downloaded 47.7% of file piece 0
# Time 17.9: Peer 3 has downloaded 47.6% of file piece 1
# Time 17.9: Peer 3 has downloaded 33.5% of file piece 2
# Time 17.9: Peer 3 has downloaded 76.2% of file piece 3
# Time 17.9: Peer 3 has downloaded 33.4% of file piece 4
# Time 17.9: Peer 3 has downloaded 47.5% of file piece 5
# Time 17.9: Peer 3 has downloaded 47.5% of file piece 6
# Time 17.9: Peer 3 has downloaded 76.0% of file piece 7
# Time 17.9: Peer 3 has downloaded 75.9% of file piece 9
# Time 17.9: Peer 4 has downloaded 33.4% of file piece 0
# Time 17.9: Peer 4 has downloaded 47.4% of file piece 1
# Time 17.9: Peer 4 has downloaded 33.3% of file piece 4
# Time 17.9: Peer 4 has downloaded 33.3% of file piece 5
# Time 18.0: Peer 1 has downloaded 34.7% of file piece 8
# Time 18.0: Peer 2 has downloaded 50.0% of file piece 0
# Time 18.0: Peer 2 has downloaded 48.7% of file piece 1
# Time 18.0: Peer 2 has downloaded 48.3% of file piece 3
# Time 18.0: Peer 2 has downloaded 34.0% of file piece 4
# Time 18.0: Peer 2 has downloaded 48.1% of file piece 5
# Time 18.0: Peer 2 has downloaded 78.2% of file piece 7
# Time 18.0: Peer 2 has downloaded 77.0% of file piece 8
# Time 18.0: Peer 3 has downloaded 47.9% of file piece 0
# Time 18.0: Peer 3 has downloaded 47.9% of file piece 1
# Time 18.0: Peer 3 has downloaded 33.7% of file piece 2
# Time 18.0: Peer 3 has downloaded 76.7% of file piece 3
# Time 18.0: Peer 3 has downloaded 33.6% of file piece 4
# Time 18.0: Peer 3 has downloaded 47.8% of file piece 5
# Time 18.0: Peer 3 has downloaded 47.8% of file piece 6
# Time 18.0: Peer 3 has downloaded 76.5% of file piece 7
# Time 18.0: Peer 3 has downloaded 76.4% of file piece 9
# Time 18.0: Peer 4 has downloaded 33.6% of file piece 0
# Time 18.0: Peer 4 has downloaded 47.7% of file piece 1
# Time 18.0: Peer 4 has downloaded 33.5% of file piece 4
# Time 18.0: Peer 4 has downloaded 33.5% of file piece 5
# Time 18.1: Peer 1 has downloaded 34.9% of file piece 8
# Time 18.1: Peer 2 has downloaded 50.2% of file piece 0
# Time 18.1: Peer 2 has downloaded 49.0% of file piece 1
# Time 18.1: Peer 2 has downloaded 48.6% of file piece 3
# Time 18.1: Peer 2 has downloaded 34.2% of file piece 4
# Time 18.1: Peer 2 has downloaded 48.4% of file piece 5
# Time 18.1: Peer 2 has downloaded 78.6% of file piece 7
# Time 18.1: Peer 2 has downloaded 77.5% of file piece 8
# Time 18.1: Peer 3 has downloaded 48.2% of file piece 0
# Time 18.1: Peer 3 has downloaded 48.1% of file piece 1
# Time 18.1: Peer 3 has downloaded 33.9% of file piece 2
# Time 18.1: Peer 3 has downloaded 77.1% of file piece 3
# Time 18.1: Peer 3 has downloaded 33.8% of file piece 4
# Time 18.1: Peer 3 has downloaded 48.1% of file piece 5
# Time 18.1: Peer 3 has downloaded 48.0% of file piece 6
# Time 18.1: Peer 3 has downloaded 76.9% of file piece 7
# Time 18.1: Peer 3 has downloaded 76.8% of file piece 9
# Time 18.1: Peer 4 has downloaded 33.8% of file piece 0
# Time 18.1: Peer 4 has downloaded 48.0% of file piece 1
# Time 18.1: Peer 4 has downloaded 33.7% of file piece 4
# Time 18.1: Peer 4 has downloaded 33.7% of file piece 5
# Time 18.2: Peer 1 has downloaded 35.1% of file piece 8
# Time 18.2: Peer 2 has downloaded 50.5% of file piece 0
# Time 18.2: Peer 2 has downloaded 49.3% of file piece 1
# Time 18.2: Peer 2 has downloaded 48.8% of file piece 3
# Time 18.2: Peer 2 has downloaded 34.4% of file piece 4
# Time 18.2: Peer 2 has downloaded 48.6% of file piece 5
# Time 18.2: Peer 2 has downloaded 79.1% of file piece 7
# Time 18.2: Peer 2 has downloaded 77.9% of file piece 8
# Time 18.2: Peer 3 has downloaded 48.5% of file piece 0
# Time 18.2: Peer 3 has downloaded 48.4% of file piece 1
# Time 18.2: Peer 3 has downloaded 34.1% of file piece 2
# Time 18.2: Peer 3 has downloaded 77.6% of file piece 3
# Time 18.2: Peer 3 has downloaded 34.0% of file piece 4
# Time 18.2: Peer 3 has downloaded 48.4% of file piece 5
# Time 18.2: Peer 3 has downloaded 48.3% of file piece 6
# Time 18.2: Peer 3 has downloaded 77.4% of file piece 7
# Time 18.2: Peer 3 has downloaded 77.3% of file piece 9
# Time 18.2: Peer 4 has downloaded 34.0% of file piece 0
# Time 18.2: Peer 4 has downloaded 48.3% of file piece 1
# Time 18.2: Peer 4 has downloaded 33.9% of file piece 4
# Time 18.2: Peer 4 has downloaded 33.9% of file piece 5
# Time 18.3: Peer 1 has downloaded 35.3% of file piece 8
# Time 18.3: Peer 2 has downloaded 50.8% of file piece 0
# Time 18.3: Peer 2 has downloaded 49.5% of file piece 1
# Time 18.3: Peer 2 has downloaded 49.1% of file piece 3
# Time 18.3: Peer 2 has downloaded 34.6% of file piece 4
# Time 18.3: Peer 2 has downloaded 48.9% of file piece 5
# Time 18.3: Peer 2 has downloaded 79.5% of file piece 7
# Time 18.3: Peer 2 has downloaded 78.4% of file piece 8
# Time 18.3: Peer 3 has downloaded 48.8% of file piece 0
# Time 18.3: Peer 3 has downloaded 48.7% of file piece 1
# Time 18.3: Peer 3 has downloaded 34.3% of file piece 2
# Time 18.3: Peer 3 has downloaded 78.0% of file piece 3
# Time 18.3: Peer 3 has downloaded 34.2% of file piece 4
# Time 18.3: Peer 3 has downloaded 48.6% of file piece 5
# Time 18.3: Peer 3 has downloaded 48.6% of file piece 6
# Time 18.3: Peer 3 has downloaded 77.8% of file piece 7
# Time 18.3: Peer 3 has downloaded 77.7% of file piece 9
# Time 18.3: Peer 4 has downloaded 34.2% of file piece 0
# Time 18.3: Peer 4 has downloaded 48.6% of file piece 1
# Time 18.3: Peer 4 has downloaded 34.1% of file piece 4
# Time 18.3: Peer 4 has downloaded 34.1% of file piece 5
# Time 18.4: Peer 1 has downloaded 35.5% of file piece 8
# Time 18.4: Peer 2 has downloaded 51.1% of file piece 0
# Time 18.4: Peer 2 has downloaded 49.8% of file piece 1
# Time 18.4: Peer 2 has downloaded 49.4% of file piece 3
# Time 18.4: Peer 2 has downloaded 34.8% of file piece 4
# Time 18.4: Peer 2 has downloaded 49.2% of file piece 5
# Time 18.4: Peer 2 has downloaded 80.0% of file piece 7
# Time 18.4: Peer 2 has downloaded 78.8% of file piece 8
# Time 18.4: Peer 3 has downloaded 49.1% of file piece 0
# Time 18.4: Peer 3 has downloaded 49.0% of file piece 1
# Time 18.4: Peer 3 has downloaded 34.5% of file piece 2
# Time 18.4: Peer 3 has downloaded 78.5% of file piece 3
# Time 18.4: Peer 3 has downloaded 34.4% of file piece 4
# Time 18.4: Peer 3 has downloaded 48.9% of file piece 5
# Time 18.4: Peer 3 has downloaded 48.9% of file piece 6
# Time 18.4: Peer 3 has downloaded 78.3% of file piece 7
# Time 18.4: Peer 3 has downloaded 78.2% of file piece 9
# Time 18.4: Peer 4 has downloaded 34.4% of file piece 0
# Time 18.4: Peer 4 has downloaded 48.8% of file piece 1
# Time 18.4: Peer 4 has downloaded 34.3% of file piece 4
# Time 18.4: Peer 4 has downloaded 34.3% of file piece 5
# Time 18.5: Peer 1 has downloaded 35.7% of file piece 8
# Time 18.5: Peer 2 has downloaded 51.4% of file piece 0
# Time 18.5: Peer 2 has downloaded 50.1% of file piece 1
# Time 18.5: Peer 2 has downloaded 49.7% of file piece 3
# Time 18.5: Peer 2 has downloaded 35.0% of file piece 4
# Time 18.5: Peer 2 has downloaded 49.5% of file piece 5
# Time 18.5: Peer 2 has downloaded 80.4% of file piece 7
# Time 18.5: Peer 2 has downloaded 79.3% of file piece 8
# Time 18.5: Peer 3 has downloaded 49.4% of file piece 0
# Time 18.5: Peer 3 has downloaded 49.3% of file piece 1
# Time 18.5: Peer 3 has downloaded 34.7% of file piece 2
# Time 18.5: Peer 3 has downloaded 78.9% of file piece 3
# Time 18.5: Peer 3 has downloaded 34.6% of file piece 4
# Time 18.5: Peer 3 has downloaded 49.2% of file piece 5
# Time 18.5: Peer 3 has downloaded 49.2% of file piece 6
# Time 18.5: Peer 3 has downloaded 78.7% of file piece 7
# Time 18.5: Peer 3 has downloaded 78.6% of file piece 9
# Time 18.5: Peer 4 has downloaded 34.5% of file piece 0
# Time 18.5: Peer 4 has downloaded 49.1% of file piece 1
# Time 18.5: Peer 4 has downloaded 34.5% of file piece 4
# Time 18.5: Peer 4 has downloaded 34.5% of file piece 5
# Time 18.6: Peer 1 has downloaded 35.8% of file piece 8
# Time 18.6: Peer 2 has downloaded 51.7% of file piece 0
# Time 18.6: Peer 2 has downloaded 50.4% of file piece 1
# Time 18.6: Peer 2 has downloaded 50.0% of file piece 3
# Time 18.6: Peer 2 has downloaded 35.2% of file piece 4
# Time 18.6: Peer 2 has downloaded 49.8% of file piece 5
# Time 18.6: Peer 2 has downloaded 80.8% of file piece 7
# Time 18.6: Peer 2 has downloaded 79.7% of file piece 8
# Time 18.6: Peer 3 has downloaded 49.6% of file piece 0
# Time 18.6: Peer 3 has downloaded 49.5% of file piece 1
# Time 18.6: Peer 3 has downloaded 34.9% of file piece 2
# Time 18.6: Peer 3 has downloaded 79.4% of file piece 3
# Time 18.6: Peer 3 has downloaded 34.8% of file piece 4
# Time 18.6: Peer 3 has downloaded 49.5% of file piece 5
# Time 18.6: Peer 3 has downloaded 49.4% of file piece 6
# Time 18.6: Peer 3 has downloaded 79.2% of file piece 7
# Time 18.6: Peer 3 has downloaded 79.1% of file piece 9
# Time 18.6: Peer 4 has downloaded 34.7% of file piece 0
# Time 18.6: Peer 4 has downloaded 49.4% of file piece 1
# Time 18.6: Peer 4 has downloaded 34.7% of file piece 4
# Time 18.6: Peer 4 has downloaded 34.7% of file piece 5
# Time 18.7: Peer 1 has downloaded 36.0% of file piece 8
# Time 18.7: Peer 2 has downloaded 51.9% of file piece 0
# Time 18.7: Peer 2 has downloaded 50.7% of file piece 1
# Time 18.7: Peer 2 has downloaded 50.2% of file piece 3
# Time 18.7: Peer 2 has downloaded 35.4% of file piece 4
# Time 18.7: Peer 2 has downloaded 50.0% of file piece 5
# Time 18.7: Peer 2 has downloaded 81.3% of file piece 7
# Time 18.7: Peer 2 has downloaded 80.2% of file piece 8
# Time 18.7: Peer 3 has downloaded 49.9% of file piece 0
# Time 18.7: Peer 3 has downloaded 49.8% of file piece 1
# Time 18.7: Peer 3 has downloaded 35.1% of file piece 2
# Time 18.7: Peer 3 has downloaded 79.8% of file piece 3
# Time 18.7: Peer 3 has downloaded 35.0% of file piece 4
# Time 18.7: Peer 3 has downloaded 49.8% of file piece 5
# Time 18.7: Peer 3 has downloaded 49.7% of file piece 6
# Time 18.7: Peer 3 has downloaded 79.6% of file piece 7
# Time 18.7: Peer 3 has downloaded 79.5% of file piece 9
# Time 18.7: Peer 4 has downloaded 34.9% of file piece 0
# Time 18.7: Peer 4 has downloaded 49.7% of file piece 1
# Time 18.7: Peer 4 has downloaded 34.9% of file piece 4
# Time 18.7: Peer 4 has downloaded 34.9% of file piece 5
# Time 18.8: Peer 1 has downloaded 36.2% of file piece 8
# Time 18.8: Peer 2 has downloaded 52.2% of file piece 0
# Time 18.8: Peer 2 has downloaded 51.0% of file piece 1
# Time 18.8: Peer 2 has downloaded 50.5% of file piece 3
# Time 18.8: Peer 2 has downloaded 35.6% of file piece 4
# Time 18.8: Peer 2 has downloaded 50.3% of file piece 5
# Time 18.8: Peer 2 has downloaded 81.7% of file piece 7
# Time 18.8: Peer 2 has downloaded 80.6% of file piece 8
# Time 18.8: Peer 3 has downloaded 50.2% of file piece 0
# Time 18.8: Peer 3 has downloaded 50.1% of file piece 1
# Time 18.8: Peer 3 has downloaded 35.3% of file piece 2
# Time 18.8: Peer 3 has downloaded 80.2% of file piece 3
# ...
# Time 47.7: Peer 1 has downloaded 93.2% of file piece 8
# Time 47.7: Peer 2 has downloaded 92.5% of file piece 4
# Time 47.7: Peer 3 has downloaded 92.2% of file piece 2
# Time 47.7: Peer 3 has downloaded 92.1% of file piece 4
# Time 47.7: Peer 4 has downloaded 92.1% of file piece 0
# Time 47.7: Peer 4 has downloaded 92.0% of file piece 4
# Time 47.7: Peer 4 has downloaded 92.0% of file piece 5
# Time 47.8: Peer 1 has downloaded 93.4% of file piece 8
# Time 47.8: Peer 2 has downloaded 92.7% of file piece 4
# Time 47.8: Peer 3 has downloaded 92.4% of file piece 2
# Time 47.8: Peer 3 has downloaded 92.3% of file piece 4
# Time 47.8: Peer 4 has downloaded 92.3% of file piece 0
# Time 47.8: Peer 4 has downloaded 92.2% of file piece 4
# Time 47.8: Peer 4 has downloaded 92.2% of file piece 5
# Time 47.9: Peer 1 has downloaded 93.6% of file piece 8
# Time 47.9: Peer 2 has downloaded 92.9% of file piece 4
# Time 47.9: Peer 3 has downloaded 92.6% of file piece 2
# Time 47.9: Peer 3 has downloaded 92.5% of file piece 4
# Time 47.9: Peer 4 has downloaded 92.5% of file piece 0
# Time 47.9: Peer 4 has downloaded 92.4% of file piece 4
# Time 47.9: Peer 4 has downloaded 92.4% of file piece 5
# Time 48.0: Peer 1 has downloaded 93.8% of file piece 8
# Time 48.0: Peer 2 has downloaded 93.1% of file piece 4
# Time 48.0: Peer 3 has downloaded 92.8% of file piece 2
# Time 48.0: Peer 3 has downloaded 92.7% of file piece 4
# Time 48.0: Peer 4 has downloaded 92.7% of file piece 0
# Time 48.0: Peer 4 has downloaded 92.6% of file piece 4
# Time 48.0: Peer 4 has downloaded 92.6% of file piece 5
# Time 48.1: Peer 1 has downloaded 94.0% of file piece 8
# Time 48.1: Peer 2 has downloaded 93.3% of file piece 4
# Time 48.1: Peer 3 has downloaded 93.0% of file piece 2
# Time 48.1: Peer 3 has downloaded 92.9% of file piece 4
# Time 48.1: Peer 4 has downloaded 92.8% of file piece 0
# Time 48.1: Peer 4 has downloaded 92.8% of file piece 4
# Time 48.1: Peer 4 has downloaded 92.8% of file piece 5
# Time 48.2: Peer 1 has downloaded 94.1% of file piece 8
# Time 48.2: Peer 2 has downloaded 93.5% of file piece 4
# Time 48.2: Peer 3 has downloaded 93.2% of file piece 2
# Time 48.2: Peer 3 has downloaded 93.1% of file piece 4
# Time 48.2: Peer 4 has downloaded 93.0% of file piece 0
# Time 48.2: Peer 4 has downloaded 93.0% of file piece 4
# Time 48.2: Peer 4 has downloaded 93.0% of file piece 5
# Time 48.3: Peer 1 has downloaded 94.3% of file piece 8
# Time 48.3: Peer 2 has downloaded 93.7% of file piece 4
# Time 48.3: Peer 3 has downloaded 93.4% of file piece 2
# Time 48.3: Peer 3 has downloaded 93.3% of file piece 4
# Time 48.3: Peer 4 has downloaded 93.2% of file piece 0
# Time 48.3: Peer 4 has downloaded 93.2% of file piece 4
# Time 48.3: Peer 4 has downloaded 93.2% of file piece 5
# Time 48.4: Peer 1 has downloaded 94.5% of file piece 8
# Time 48.4: Peer 2 has downloaded 93.9% of file piece 4
# Time 48.4: Peer 3 has downloaded 93.6% of file piece 2
# Time 48.4: Peer 3 has downloaded 93.5% of file piece 4
# Time 48.4: Peer 4 has downloaded 93.4% of file piece 0
# Time 48.4: Peer 4 has downloaded 93.4% of file piece 4
# Time 48.4: Peer 4 has downloaded 93.4% of file piece 5
# Time 48.5: Peer 1 has downloaded 94.7% of file piece 8
# Time 48.5: Peer 2 has downloaded 94.1% of file piece 4
# Time 48.5: Peer 3 has downloaded 93.8% of file piece 2
# Time 48.5: Peer 3 has downloaded 93.7% of file piece 4
# Time 48.5: Peer 4 has downloaded 93.6% of file piece 0
# Time 48.5: Peer 4 has downloaded 93.6% of file piece 4
# Time 48.5: Peer 4 has downloaded 93.6% of file piece 5
# Time 48.6: Peer 1 has downloaded 94.9% of file piece 8
# Time 48.6: Peer 2 has downloaded 94.2% of file piece 4
# Time 48.6: Peer 3 has downloaded 94.0% of file piece 2
# Time 48.6: Peer 3 has downloaded 93.9% of file piece 4
# Time 48.6: Peer 4 has downloaded 93.8% of file piece 0
# Time 48.6: Peer 4 has downloaded 93.8% of file piece 4
# Time 48.6: Peer 4 has downloaded 93.8% of file piece 5
# Time 48.7: Peer 1 has downloaded 95.1% of file piece 8
# Time 48.7: Peer 2 has downloaded 94.4% of file piece 4
# Time 48.7: Peer 3 has downloaded 94.2% of file piece 2
# Time 48.7: Peer 3 has downloaded 94.1% of file piece 4
# Time 48.7: Peer 4 has downloaded 94.0% of file piece 0
# Time 48.7: Peer 4 has downloaded 94.0% of file piece 4
# Time 48.7: Peer 4 has downloaded 94.0% of file piece 5
# Time 48.8: Peer 1 has downloaded 95.3% of file piece 8
# Time 48.8: Peer 2 has downloaded 94.6% of file piece 4
# Time 48.8: Peer 3 has downloaded 94.4% of file piece 2
# Time 48.8: Peer 3 has downloaded 94.3% of file piece 4
# Time 48.8: Peer 4 has downloaded 94.2% of file piece 0
# Time 48.8: Peer 4 has downloaded 94.2% of file piece 4
# Time 48.8: Peer 4 has downloaded 94.1% of file piece 5
# Time 48.9: Peer 1 has downloaded 95.5% of file piece 8
# Time 48.9: Peer 2 has downloaded 94.8% of file piece 4
# Time 48.9: Peer 3 has downloaded 94.6% of file piece 2
# Time 48.9: Peer 3 has downloaded 94.5% of file piece 4
# Time 48.9: Peer 4 has downloaded 94.4% of file piece 0
# Time 48.9: Peer 4 has downloaded 94.4% of file piece 4
# Time 48.9: Peer 4 has downloaded 94.3% of file piece 5
# Time 49.0: Peer 1 has downloaded 95.7% of file piece 8
# Time 49.0: Peer 2 has downloaded 95.0% of file piece 4
# Time 49.0: Peer 3 has downloaded 94.8% of file piece 2
# Time 49.0: Peer 3 has downloaded 94.7% of file piece 4
# Time 49.0: Peer 4 has downloaded 94.6% of file piece 0
# Time 49.0: Peer 4 has downloaded 94.6% of file piece 4
# Time 49.0: Peer 4 has downloaded 94.5% of file piece 5
# Time 49.1: Peer 1 has downloaded 95.9% of file piece 8
# Time 49.1: Peer 2 has downloaded 95.2% of file piece 4
# Time 49.1: Peer 3 has downloaded 95.0% of file piece 2
# Time 49.1: Peer 3 has downloaded 94.9% of file piece 4
# Time 49.1: Peer 4 has downloaded 94.8% of file piece 0
# Time 49.1: Peer 4 has downloaded 94.8% of file piece 4
# Time 49.1: Peer 4 has downloaded 94.7% of file piece 5
# Time 49.2: Peer 1 has downloaded 96.1% of file piece 8
# Time 49.2: Peer 2 has downloaded 95.4% of file piece 4
# Time 49.2: Peer 3 has downloaded 95.2% of file piece 2
# Time 49.2: Peer 3 has downloaded 95.1% of file piece 4
# Time 49.2: Peer 4 has downloaded 95.0% of file piece 0
# Time 49.2: Peer 4 has downloaded 95.0% of file piece 4
# Time 49.2: Peer 4 has downloaded 94.9% of file piece 5
# Time 49.3: Peer 1 has downloaded 96.3% of file piece 8
# Time 49.3: Peer 2 has downloaded 95.6% of file piece 4
# Time 49.3: Peer 3 has downloaded 95.4% of file piece 2
# Time 49.3: Peer 3 has downloaded 95.3% of file piece 4
# Time 49.3: Peer 4 has downloaded 95.2% of file piece 0
# Time 49.3: Peer 4 has downloaded 95.2% of file piece 4
# Time 49.3: Peer 4 has downloaded 95.1% of file piece 5
# Time 49.4: Peer 1 has downloaded 96.5% of file piece 8
# Time 49.4: Peer 2 has downloaded 95.8% of file piece 4
# Time 49.4: Peer 3 has downloaded 95.6% of file piece 2
# Time 49.4: Peer 3 has downloaded 95.5% of file piece 4
# Time 49.4: Peer 4 has downloaded 95.4% of file piece 0
# Time 49.4: Peer 4 has downloaded 95.4% of file piece 4
# Time 49.4: Peer 4 has downloaded 95.3% of file piece 5
# Time 49.5: Peer 1 has downloaded 96.7% of file piece 8
# Time 49.5: Peer 2 has downloaded 96.0% of file piece 4
# Time 49.5: Peer 3 has downloaded 95.8% of file piece 2
# Time 49.5: Peer 3 has downloaded 95.7% of file piece 4
# Time 49.5: Peer 4 has downloaded 95.6% of file piece 0
# Time 49.5: Peer 4 has downloaded 95.6% of file piece 4
# Time 49.5: Peer 4 has downloaded 95.5% of file piece 5
# Time 49.6: Peer 1 has downloaded 96.9% of file piece 8
# Time 49.6: Peer 2 has downloaded 96.2% of file piece 4
# Time 49.6: Peer 3 has downloaded 96.0% of file piece 2
# Time 49.6: Peer 3 has downloaded 95.9% of file piece 4
# Time 49.6: Peer 4 has downloaded 95.8% of file piece 0
# Time 49.6: Peer 4 has downloaded 95.8% of file piece 4
# Time 49.6: Peer 4 has downloaded 95.7% of file piece 5
# Time 49.7: Peer 1 has downloaded 97.1% of file piece 8
# Time 49.7: Peer 2 has downloaded 96.4% of file piece 4
# Time 49.7: Peer 3 has downloaded 96.2% of file piece 2
# Time 49.7: Peer 3 has downloaded 96.1% of file piece 4
# Time 49.7: Peer 4 has downloaded 96.0% of file piece 0
# Time 49.7: Peer 4 has downloaded 96.0% of file piece 4
# Time 49.7: Peer 4 has downloaded 95.9% of file piece 5
# Time 49.8: Peer 1 has downloaded 97.3% of file piece 8
# Time 49.8: Peer 2 has downloaded 96.6% of file piece 4
# Time 49.8: Peer 3 has downloaded 96.4% of file piece 2
# Time 49.8: Peer 3 has downloaded 96.3% of file piece 4
# Time 49.8: Peer 4 has downloaded 96.2% of file piece 0
# Time 49.8: Peer 4 has downloaded 96.2% of file piece 4
# Time 49.8: Peer 4 has downloaded 96.1% of file piece 5
# Time 49.9: Peer 1 has downloaded 97.5% of file piece 8
# Time 49.9: Peer 2 has downloaded 96.8% of file piece 4
# Time 49.9: Peer 3 has downloaded 96.6% of file piece 2
# Time 49.9: Peer 3 has downloaded 96.5% of file piece 4
# Time 49.9: Peer 4 has downloaded 96.4% of file piece 0
# Time 49.9: Peer 4 has downloaded 96.3% of file piece 4
# Time 49.9: Peer 4 has downloaded 96.3% of file piece 5
# Time 50.0: Peer 1 has downloaded 97.7% of file piece 8
# Time 50.0: Peer 2 has downloaded 97.0% of file piece 4
# Time 50.0: Peer 3 has downloaded 96.8% of file piece 2
# Time 50.0: Peer 3 has downloaded 96.7% of file piece 4
# Time 50.0: Peer 4 has downloaded 96.6% of file piece 0
# Time 50.0: Peer 4 has downloaded 96.5% of file piece 4
# Time 50.0: Peer 4 has downloaded 96.5% of file piece 5
# Time 50.1: Peer 1 has downloaded 97.9% of file piece 8
# Time 50.1: Peer 2 has downloaded 97.2% of file piece 4
# Time 50.1: Peer 3 has downloaded 97.0% of file piece 2
# Time 50.1: Peer 3 has downloaded 96.9% of file piece 4
# Time 50.1: Peer 4 has downloaded 96.8% of file piece 0
# Time 50.1: Peer 4 has downloaded 96.7% of file piece 4
# Time 50.1: Peer 4 has downloaded 96.7% of file piece 5
# Time 50.2: Peer 1 has downloaded 98.1% of file piece 8
# Time 50.2: Peer 2 has downloaded 97.4% of file piece 4
# Time 50.2: Peer 3 has downloaded 97.2% of file piece 2
# Time 50.2: Peer 3 has downloaded 97.1% of file piece 4
# Time 50.2: Peer 4 has downloaded 97.0% of file piece 0
# Time 50.2: Peer 4 has downloaded 96.9% of file piece 4
# Time 50.2: Peer 4 has downloaded 96.9% of file piece 5
# Time 50.3: Peer 1 has downloaded 98.3% of file piece 8
# Time 50.3: Peer 2 has downloaded 97.6% of file piece 4
# Time 50.3: Peer 3 has downloaded 97.4% of file piece 2
# Time 50.3: Peer 3 has downloaded 97.3% of file piece 4
# Time 50.3: Peer 4 has downloaded 97.2% of file piece 0
# Time 50.3: Peer 4 has downloaded 97.1% of file piece 4
# Time 50.3: Peer 4 has downloaded 97.1% of file piece 5
# Time 50.4: Peer 1 has downloaded 98.5% of file piece 8
# Time 50.4: Peer 2 has downloaded 97.8% of file piece 4
# Time 50.4: Peer 3 has downloaded 97.6% of file piece 2
# Time 50.4: Peer 3 has downloaded 97.4% of file piece 4
# Time 50.4: Peer 4 has downloaded 97.4% of file piece 0
# Time 50.4: Peer 4 has downloaded 97.3% of file piece 4
# Time 50.4: Peer 4 has downloaded 97.3% of file piece 5
# Time 50.5: Peer 1 has downloaded 98.7% of file piece 8
# Time 50.5: Peer 2 has downloaded 98.0% of file piece 4
# Time 50.5: Peer 3 has downloaded 97.8% of file piece 2
# Time 50.5: Peer 3 has downloaded 97.6% of file piece 4
# Time 50.5: Peer 4 has downloaded 97.6% of file piece 0
# Time 50.5: Peer 4 has downloaded 97.5% of file piece 4
# Time 50.5: Peer 4 has downloaded 97.5% of file piece 5
# Time 50.6: Peer 1 has downloaded 98.9% of file piece 8
# Time 50.6: Peer 2 has downloaded 98.2% of file piece 4
# Time 50.6: Peer 3 has downloaded 98.0% of file piece 2
# Time 50.6: Peer 3 has downloaded 97.8% of file piece 4
# Time 50.6: Peer 4 has downloaded 97.8% of file piece 0
# Time 50.6: Peer 4 has downloaded 97.7% of file piece 4
# Time 50.6: Peer 4 has downloaded 97.7% of file piece 5
# Time 50.7: Peer 1 has downloaded 99.1% of file piece 8
# Time 50.7: Peer 2 has downloaded 98.4% of file piece 4
# Time 50.7: Peer 3 has downloaded 98.2% of file piece 2
# Time 50.7: Peer 3 has downloaded 98.0% of file piece 4
# Time 50.7: Peer 4 has downloaded 98.0% of file piece 0
# Time 50.7: Peer 4 has downloaded 97.9% of file piece 4
# Time 50.7: Peer 4 has downloaded 97.9% of file piece 5
# Time 50.8: Peer 1 has downloaded 99.3% of file piece 8
# Time 50.8: Peer 2 has downloaded 98.6% of file piece 4
# Time 50.8: Peer 3 has downloaded 98.4% of file piece 2
# Time 50.8: Peer 3 has downloaded 98.2% of file piece 4
# Time 50.8: Peer 4 has downloaded 98.2% of file piece 0
# Time 50.8: Peer 4 has downloaded 98.1% of file piece 4
# Time 50.8: Peer 4 has downloaded 98.1% of file piece 5
# Time 50.9: Peer 1 has downloaded 99.5% of file piece 8
# Time 50.9: Peer 2 has downloaded 98.8% of file piece 4
# Time 50.9: Peer 3 has downloaded 98.5% of file piece 2
# Time 50.9: Peer 3 has downloaded 98.4% of file piece 4
# Time 50.9: Peer 4 has downloaded 98.4% of file piece 0
# Time 50.9: Peer 4 has downloaded 98.3% of file piece 4
# Time 50.9: Peer 4 has downloaded 98.3% of file piece 5
# Time 51.0: Peer 1 has downloaded 99.7% of file piece 8
# Time 51.0: Peer 2 has downloaded 99.0% of file piece 4
# Time 51.0: Peer 3 has downloaded 98.7% of file piece 2
# Time 51.0: Peer 3 has downloaded 98.6% of file piece 4
# Time 51.0: Peer 4 has downloaded 98.6% of file piece 0
# Time 51.0: Peer 4 has downloaded 98.5% of file piece 4
# Time 51.0: Peer 4 has downloaded 98.5% of file piece 5
# Time 51.1: Peer 1 has downloaded 99.9% of file piece 8
# Time 51.1: Peer 2 has downloaded 99.2% of file piece 4
# Time 51.1: Peer 3 has downloaded 98.9% of file piece 2
# Time 51.1: Peer 3 has downloaded 98.8% of file piece 4
# Time 51.1: Peer 4 has downloaded 98.8% of file piece 0
# Time 51.1: Peer 4 has downloaded 98.7% of file piece 4
# Time 51.1: Peer 4 has downloaded 98.7% of file piece 5
# Time 51.2: Peer 1 has downloaded 100.1% of file piece 8
# Time 51.2: Peer 1 completed download of file piece 8
# Time 51.2: Peer 2 has downloaded 99.4% of file piece 4
# Time 51.2: Peer 3 has downloaded 99.1% of file piece 2
# Time 51.2: Peer 3 has downloaded 99.0% of file piece 4
# Time 51.2: Peer 4 has downloaded 99.0% of file piece 0
# Time 51.2: Peer 4 has downloaded 98.9% of file piece 4
# Time 51.2: Peer 4 has downloaded 98.9% of file piece 5
# Peer 1 has completed downloading all file pieces, stopping requests
# Time 51.3: Peer 2 has downloaded 99.6% of file piece 4
# Time 51.3: Peer 3 has downloaded 99.4% of file piece 2
# Time 51.3: Peer 3 has downloaded 99.3% of file piece 4
# Time 51.3: Peer 4 has downloaded 99.2% of file piece 0
# Time 51.3: Peer 4 has downloaded 99.1% of file piece 4
# Time 51.3: Peer 4 has downloaded 99.1% of file piece 5
# Time 51.4: Peer 2 has downloaded 99.8% of file piece 4
# Time 51.4: Peer 3 has downloaded 99.6% of file piece 2
# Time 51.4: Peer 3 has downloaded 99.5% of file piece 4
# Time 51.4: Peer 4 has downloaded 99.4% of file piece 0
# Time 51.4: Peer 4 has downloaded 99.4% of file piece 4
# Time 51.4: Peer 4 has downloaded 99.3% of file piece 5
# Time 51.5: Peer 2 has downloaded 100.1% of file piece 4
# Time 51.5: Peer 2 completed download of file piece 4
# Time 51.5: Peer 3 has downloaded 99.8% of file piece 2
# Time 51.5: Peer 3 has downloaded 99.7% of file piece 4
# Time 51.5: Peer 4 has downloaded 99.6% of file piece 0
# Time 51.5: Peer 4 has downloaded 99.6% of file piece 4
# Time 51.5: Peer 4 has downloaded 99.6% of file piece 5
# Peer 2 has completed downloading all file pieces, stopping requests
# Time 51.6: Peer 3 has downloaded 100.1% of file piece 2
# Time 51.6: Peer 3 completed download of file piece 2
# Time 51.6: Peer 3 has downloaded 100.0% of file piece 4
# Time 51.6: Peer 4 has downloaded 99.9% of file piece 0
# Time 51.6: Peer 4 has downloaded 99.9% of file piece 4
# Time 51.6: Peer 4 has downloaded 99.8% of file piece 5
# Time 51.7: Peer 3 has downloaded 100.3% of file piece 4
# Time 51.7: Peer 3 completed download of file piece 4
# Time 51.7: Peer 4 has downloaded 100.3% of file piece 0
# Time 51.7: Peer 4 completed download of file piece 0
# Time 51.7: Peer 4 has downloaded 100.2% of file piece 4
# Time 51.7: Peer 4 completed download of file piece 4
# Time 51.7: Peer 4 has downloaded 100.2% of file piece 5
# Time 51.7: Peer 4 completed download of file piece 5
# Peer 3 has completed downloading all file pieces, stopping requests
# Peer 4 has completed downloading all file pieces, stopping requests
